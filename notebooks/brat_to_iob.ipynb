# %% [markdown]
# # Эксперименты с форматом brat

# %%
from typing import List, Tuple, Iterable
from pathlib import Path
import nltk
from collections import namedtuple
from nltk.tokenize import WordPunctTokenizer, RegexpTokenizer, PunktSentenceTokenizer

# %%
brat_dir = Path('/home/max/datasets/RuREBus_data/brat')
brat_doc_name = '20103011022200910379001_0_part_0'
brat_text_path = (brat_dir / brat_doc_name).with_suffix('.txt')
brat_ann_path = brat_text_path.with_suffix('.ann')

# %%
text = brat_text_path.open().read()

# %%
print(text[:200])

# %%
Entity = namedtuple('Entity', 'id label position text')
Position = namedtuple('Position', 'start end')

def read_annotation(path: Path) -> List[Entity]:
    entities = [Entity(id_, label, Position(int(start), int(end)), phrase) for id_, label, start, end, phrase in
                ((id_, *part.split(), phrase.rstrip()) for id_, part, phrase in
                (s.split('\t') for s in path.open() if s.startswith('T')))]
    return sorted(entities, key=lambda e: e.position.start)

# %%
annotation = read_annotation(brat_ann_path)

# %%
annotation[:10]
# Out:
# [Entity(id='T2', label='BIN', position=Position(start=26, end=37), text='УТВЕРЖДЕНИИ'),
#  Entity(id='T3', label='BIN', position=Position(start=73, end=81), text='РАЗВИТИЯ'),
#  Entity(id='T6', label='BIN', position=Position(start=112, end=118), text='Принят'),
#  Entity(id='T7', label='BIN', position=Position(start=211, end=220), text='Утвердить'),
#  Entity(id='T8', label='BIN', position=Position(start=268, end=276), text='развития'),
#  Entity(id='T10', label='BIN', position=Position(start=334, end=349), text='вступает в силу'),
#  Entity(id='T14', label='BIN', position=Position(start=509, end=520), text='утверждении'),
#  Entity(id='T16', label='BIN', position=Position(start=631, end=639), text='РАЗВИТИЯ'),
#  Entity(id='T20', label='BIN', position=Position(start=756, end=771), text='входит в состав'),
#  Entity(id='T22', label='MET', position=Position(start=825, end=848), text='Площадь территории края')]

# %%
_, _, (start, end), phrase = annotation[0]

# %%
assert text[start: end] == phrase

# %%
text[start: end]

# %% [markdown]
# # Разбиваем текст на предложения и токены.

# %%
sent_detector = nltk.data.load('tokenizers/punkt/russian.pickle')

# %%
test_text = 'У попа была "собака",\nон ее любил. Она съела. Он ее убил. Kek!'

# %%
list(sent_detector.span_tokenize_sents(test_text))
# Out:
# [[(0, 32), (33, 43), (44, 55)], [], [(0, 4)]]

# %%
test_text[44:55]
# Out:
# []

# %%
import re, string

# %%
def tokenize_text(sent_tokenizer: PunktSentenceTokenizer, 
                  word_tokenizer: RegexpTokenizer,
                  text: str) -> Iterable[List[Tuple[int, int]]]:
    paragraphs = text.split('\n')
    para_sents = list(sent_tokenizer.span_tokenize_sents(paragraphs))
    parargraph_start = 0
    for para_sents, para_text in zip(para_sents, paragraphs):
        for sent_start, sent_end in para_sents:
            sentence = []
            sent_text = text[parargraph_start + sent_start: parargraph_start + sent_end]
            for token_start, token_end in word_tokenizer.span_tokenize(sent_text):
                offset = parargraph_start + sent_start
                sentence.append((offset + token_start, offset + token_end))
            yield sentence
        parargraph_start += len(para_text) + 1

# %%
sentences = list(tokenize_text(sent_detector, RegexpTokenizer(f'\w+|[{re.escape(string.punctuation)}]|\S+'), text))

# %% [markdown]
# # Строим IOB

# %%
def build_iob(
    text: str,
    sentences: Iterable[List[Tuple[int, int]]],
    annotation: List[Entity]) -> Iterable[str]:
    entity_index = 0
    entity = annotation[entity_index] if annotation else None
    label = None
    entity_started = False
    for sent in sentences:
        for start, end in sent:
            if entity and start >= entity.position.end:
                entity_index += 1
                entity = annotation[entity_index] if len(annotation) > entity_index else None
                entity_started = False
            if entity and start >= entity.position.start and end <= entity.position.end:
                if not entity_started and label == entity.label:
                    prefix = 'B'
                else:
                    prefix = 'I'
                label = entity.label
                tag = prefix + '-' + label
                entity_started = True
            else:
                label = 'O'
                tag = label
            yield '\t'.join(map(str, (text[start: end], tag, start, end)))
        yield ''

# %%
for s in build_iob(text, sentences, annotation):
    print(s)
# Out:
# АЛТАЙСКИЙ	O	0	9
# КРАЙ	O	10	14
#
# ЗАКОН	O	16	21
#
# ОБ	O	23	25
# УТВЕРЖДЕНИИ	I-BIN	26	37
# СТРАТЕГИИ	O	38	47
# СОЦИАЛЬНО	O	48	57
# -	O	57	58
# ЭКОНОМИЧЕСКОГО	O	58	72
# РАЗВИТИЯ	I-BIN	73	81
#
# АЛТАЙСКОГО	O	82	92
# КРАЯ	O	93	97
# ДО	O	98	100
# 2025	O	101	105
# ГОДА	O	106	110
#
# Принят	I-BIN	112	118
#
# Постановлением	O	119	133
# Алтайского	O	134	144
# краевого	O	145	153
#
# Законодательного	O	154	170
# Собрания	O	171	179
#
# от	O	180	182
# 19	O	183	185
# .	O	185	186
# 11	O	186	188
# .	O	188	189
# 2012	O	189	193
# N	O	194	195
# 569	O	196	199
#
# Статья	O	201	207
# 1	O	208	209
#
# Утвердить	I-BIN	211	220
# прилагаемую	O	221	232
# стратегию	O	233	242
# социально	O	243	252
# -	O	252	253
# экономического	O	253	267
# развития	I-BIN	268	276
# Алтайского	O	277	287
# края	O	288	292
# до	O	293	295
# 2025	O	296	300
# года	O	301	305
# .	O	305	306
#
# Статья	O	308	314
# 2	O	315	316
#
# Настоящий	O	318	327
# Закон	O	328	333
# вступает	I-BIN	334	342
# в	I-BIN	343	344
# силу	I-BIN	345	349
# со	O	350	352
# дня	O	353	356
# его	O	357	360
# официального	O	361	373
# опубликования	O	374	387
# .	O	387	388
#
# Губернатор	O	390	400
#
# Алтайского	O	401	411
# края	O	412	416
#
# А	O	417	418
# .	O	418	419
# Б	O	419	420
# .	O	420	421
# КАРЛИН	O	422	428
#
# г	O	429	430
# .	O	430	431
# Барнаул	O	432	439
#
# 21	O	440	442
# ноября	O	443	449
# 2012	O	450	454
# года	O	455	459
#
# N	O	460	461
# 86	O	462	464
# -	O	464	465
# ЗС	O	465	467
#
# Приложение	O	469	479
#
# к	O	480	481
# Закону	O	482	488
#
# Алтайского	O	489	499
# края	O	500	504
#
# "	O	505	506
# Об	O	506	508
# утверждении	I-BIN	509	520
# стратегии	O	521	530
#
# социально	O	531	540
# -	O	540	541
# экономического	O	541	555
# развития	O	556	564
#
# Алтайского	O	565	575
# края	O	576	580
# до	O	581	583
# 2025	O	584	588
# года	O	589	593
# "	O	593	594
#
# СТРАТЕГИЯ	O	596	605
#
# СОЦИАЛЬНО	O	606	615
# -	O	615	616
# ЭКОНОМИЧЕСКОГО	O	616	630
# РАЗВИТИЯ	I-BIN	631	639
# АЛТАЙСКОГО	O	640	650
# КРАЯ	O	651	655
#
# ДО	O	656	658
# 2025	O	659	663
# ГОДА	O	664	668
#
# 1	O	670	671
# .	O	671	672
#
# Анализ	O	673	679
# текущего	O	680	688
# социально	O	689	698
# -	O	698	699
# экономического	O	699	713
# состояния	O	714	723
#
# Алтайского	O	724	734
# края	O	735	739
#
# Алтайский	O	741	750
# край	O	751	755
# входит	I-BIN	756	762
# в	I-BIN	763	764
# состав	I-BIN	765	771
# Сибирского	O	772	782
# федерального	O	783	795
# округа	O	796	802
# Российской	O	803	813
# Федерации	O	814	823
# .	O	823	824
#
# Площадь	I-MET	825	832
# территории	I-MET	833	843
# края	I-MET	844	848
# составляет	I-BIN	849	859
# 168	O	860	863
# тыс	O	864	867
# .	O	867	868
# кв	O	869	871
# .	O	871	872
# км	O	873	875
# (	O	876	877
# около	O	877	882
# 1	O	883	884
# %	O	885	886
# территории	I-MET	887	897
# России	I-MET	898	904
# )	O	904	905
# .	O	905	906
#
# Средне	I-MET	907	913
# годовая	I-MET	914	921
# численность	I-MET	922	933
# населения	I-MET	934	943
# края	I-MET	944	948
# за	O	949	951
# 2011	O	952	956
# год	O	957	960
# составила	I-BIN	961	970
# 2412	O	971	975
# ,	O	975	976
# 3	O	976	977
# тыс	O	978	981
# .	O	981	982
# человек	O	983	990
# (	O	991	992
# 1	O	992	993
# ,	O	993	994
# 7	O	994	995
# %	O	996	997
# населения	I-MET	998	1007
# России	I-MET	1008	1014
# )	O	1014	1015
# ,	O	1015	1016
# численность	I-MET	1017	1028
# занятых	I-MET	1029	1036
# в	I-MET	1037	1038
# экономике	I-MET	1039	1048
# -	O	1049	1050
# 1075	O	1051	1055
# ,	O	1055	1056
# 6	O	1056	1057
# тыс	O	1058	1061
# .	O	1061	1062
# человек	O	1063	1070
# (	O	1071	1072
# 1	O	1072	1073
# ,	O	1073	1074
# 6	O	1074	1075
# %	O	1076	1077
# общего	I-MET	1078	1084
# числа	I-MET	1085	1090
# занятых	I-MET	1091	1098
# в	I-MET	1099	1100
# экономике	I-MET	1101	1110
# страны	I-MET	1111	1117
# )	O	1117	1118
# .	O	1118	1119
#
# Отличительной	O	1120	1133
# особенностью	O	1134	1146
# края	O	1147	1151
# является	O	1152	1160
# высокая	I-QUA	1161	1168
# доля	I-MET	1169	1173
# сельского	I-MET	1174	1183
# населения	I-MET	1184	1193
# -	O	1194	1195
# 44	O	1196	1198
# ,	O	1198	1199
# 8	O	1199	1200
# %	O	1201	1202
# (	O	1203	1204
# по	O	1204	1206
# Сибирскому	O	1207	1217
# федеральному	O	1218	1230
# округу	O	1231	1237
# -	O	1238	1239
# 27	O	1240	1242
# ,	O	1242	1243
# 8	O	1243	1244
# %	O	1245	1246
# ,	O	1246	1247
# по	O	1248	1250
# России	O	1251	1257
# -	O	1258	1259
# 26	O	1260	1262
# ,	O	1262	1263
# 1	O	1263	1264
# %	O	1265	1266
# )	O	1266	1267
# .	O	1267	1268
#
# По	O	1269	1271
# плотности	I-MET	1272	1281
# населения	I-MET	1282	1291
# Алтайский	O	1292	1301
# край	O	1302	1306
# занимает	I-BIN	1307	1315
# лидирующее	I-QUA	1316	1326
# положение	I-MET	1327	1336
# в	I-MET	1337	1338
# округе	I-MET	1339	1345
# :	O	1345	1346
# она	O	1347	1350
# практически	O	1351	1362
# в	I-CMP	1363	1364
# два	I-CMP	1365	1368
# раза	I-CMP	1369	1373
# выше	I-CMP	1374	1378
# ,	O	1378	1379
# чем	O	1380	1383
# в	O	1384	1385
# среднем	O	1386	1393
# по	O	1394	1396
# России	O	1397	1403
# .	O	1403	1404
#
# Средняя	I-MET	1405	1412
# плотность	I-MET	1413	1422
# населения	I-MET	1423	1432
# в	O	1433	1434
# Алтайском	O	1435	1444
# крае	O	1445	1449
# составляет	I-BIN	1450	1460
# 14	O	1461	1463
# ,	O	1463	1464
# 4	O	1464	1465
# человека	O	1466	1474
# на	O	1475	1477
# 1	O	1478	1479
# кв	O	1480	1482
# .	O	1482	1483
# км	O	1484	1486
# .	O	1486	1487
#
# Высокая	I-QUA	1488	1495
# концентрация	I-MET	1496	1508
# численности	I-MET	1509	1520
# населения	I-MET	1521	1530
# отмечается	I-BIN	1531	1541
# в	O	1542	1543
# городах	O	1544	1551
# :	O	1551	1552
# Барнауле	O	1553	1561
# ,	O	1561	1562
# Бийске	O	1563	1569
# и	O	1570	1571
# Рубцовске	O	1572	1581
# ,	O	1581	1582
# где	O	1583	1586
# проживают	I-BIN	1587	1596
# 28	O	1597	1599
# ,	O	1599	1600
# 3	O	1600	1601
# %	O	1602	1603
# ,	O	1603	1604
# 9	O	1605	1606
# ,	O	1606	1607
# 0	O	1607	1608
# %	O	1609	1610
# и	O	1611	1612
# 6	O	1613	1614
# ,	O	1614	1615
# 1	O	1615	1616
# %	O	1617	1618
# населения	I-SOC	1619	1628
# края	I-SOC	1629	1633
# соответственно	O	1634	1648
# .	O	1648	1649
#
# Плотность	I-MET	1650	1659
# населения	I-MET	1660	1669
# в	O	1670	1671
# муниципальных	I-INST	1672	1685
# районах	I-INST	1686	1693
# колеблется	O	1694	1704
# от	O	1705	1707
# 1	O	1708	1709
# ,	O	1709	1710
# 8	O	1710	1711
# до	O	1712	1714
# 18	O	1715	1717
# ,	O	1717	1718
# 3	O	1718	1719
# чел	O	1720	1723
# .	O	1723	1724
# /	O	1724	1725
# кв	O	1725	1727
# .	O	1727	1728
#
# км	O	1729	1731
# .	O	1731	1732
#
# В	O	1733	1734
# административный	I-INST	1735	1751
# состав	I-INST	1752	1758
# края	I-INST	1759	1763
# входят	I-BIN	1764	1770
# 11	O	1771	1773
# городских	I-INST	1774	1783
# округов	I-INST	1784	1791
# ,	O	1791	1792
# 59	O	1793	1795
# муниципальных	I-INST	1796	1809
# районов	I-INST	1810	1817
# ,	O	1817	1818
# 6	O	1819	1820
# городских	O	1821	1830
# и	O	1831	1832
# 660	O	1833	1836
# сельских	I-INST	1837	1845
# поселений	I-INST	1846	1855
# .	O	1855	1856
#
# Современное	I-MET	1857	1868
# гео	I-MET	1869	1872
# экономическое	I-MET	1873	1886
# положение	I-MET	1887	1896
# Алтайского	I-MET	1897	1907
# края	I-MET	1908	1912
# определяется	I-BIN	1913	1925
# его	O	1926	1929
# приграничным	O	1930	1942
# расположением	O	1943	1956
# по	O	1957	1959
# отношению	O	1960	1969
# к	O	1970	1971
# Республике	O	1972	1982
# Казахстан	O	1983	1992
# ,	O	1992	1993
# близостью	O	1994	2003
# к	O	2004	2005
# крупнейшим	I-INST	2006	2016
# промышленным	I-INST	2017	2029
# центрам	I-INST	2030	2037
# Сибири	I-INST	2038	2044
# (	O	2045	2046
# Новосибирск	O	2046	2057
# ,	O	2057	2058
# Кемерово	O	2059	2067
# ,	O	2067	2068
# Новокузнецк	O	2069	2080
# ,	O	2080	2081
# Томск	O	2082	2087
# ,	O	2087	2088
# Красноярск	O	2089	2099
# )	O	2099	2100
# ,	O	2100	2101
# прохождением	O	2102	2114
# по	O	2115	2117
# его	O	2118	2121
# территории	O	2122	2132
# транспортных	I-ECO	2133	2145
# коммуникаций	I-ECO	2146	2158
# федерального	I-ECO	2159	2171
# и	I-ECO	2172	2173
# международного	I-ECO	2174	2188
# значения	I-ECO	2189	2197
# .	O	2197	2198
#
# Приграничное	O	2199	2211
# положение	O	2212	2221
# Алтайского	O	2222	2232
# края	O	2233	2237
# создает	I-ACT	2238	2245
# возможности	I-ACT	2246	2257
# для	O	2258	2261
# интеграции	I-ACT	2262	2272
# края	I-ACT	2273	2277
# в	I-ACT	2278	2279
# межгосударственное	I-ACT	2280	2298
# сотрудничество	I-ACT	2299	2313
# в	O	2314	2315
# Азиатском	I-INST	2316	2325
# регионе	I-INST	2326	2333
# (	O	2334	2335
# Казахстан	O	2335	2344
# ,	O	2344	2345
# Китай	O	2346	2351
# ,	O	2351	2352
# Монголия	O	2353	2361
# )	O	2361	2362
# .	O	2362	2363
#
# Экономика	I-ECO	2364	2373
# Алтайского	I-INST	2374	2384
# края	I-INST	2385	2389
# представляет	O	2390	2402
# собой	O	2403	2408
# многоотраслевой	O	2409	2424
# комплекс	O	2425	2433
# .	O	2433	2434
#
# Основными	O	2435	2444
# видами	I-ECO	2445	2451
# экономической	I-ECO	2452	2465
# деятельности	I-ECO	2466	2478
# являются	O	2479	2487
# обрабатывающие	I-ECO	2488	2502
# производства	I-ECO	2503	2515
# ,	O	2515	2516
# оптовая	I-ECO	2517	2524
# и	I-ECO	2525	2526
# розничная	I-ECO	2527	2536
# торговля	I-ECO	2537	2545
# ,	O	2545	2546
# сельское	I-ECO	2547	2555
# и	I-ECO	2556	2557
# лесное	I-ECO	2558	2564
# хозяйство	I-ECO	2565	2574
# ,	O	2574	2575
# транспорт	I-ECO	2576	2585
# и	I-ECO	2586	2587
# связь	I-ECO	2588	2593
# (	O	2594	2595
# рис	O	2595	2598
# .	O	2598	2599
# 1	O	2600	2601
# )	O	2601	2602
# .	O	2602	2603
#
# В	O	2604	2605
# структуре	O	2606	2615
# валового	I-MET	2616	2624
# регионального	I-MET	2625	2638
# продукта	I-MET	2639	2647
# ,	O	2647	2648
# по	O	2649	2651
# данным	O	2652	2658
# за	O	2659	2661
# 2010	O	2662	2666
# год	O	2667	2670
# ,	O	2670	2671
# значительный	O	2672	2684
# удельный	I-MET	2685	2693
# вес	I-MET	2694	2697
# занимает	O	2698	2706
# торговля	I-ECO	2707	2715
# (	O	2716	2717
# 18	O	2717	2719
# ,	O	2719	2720
# 9	O	2720	2721
# %	O	2722	2723
# против	O	2724	2730
# 19	O	2731	2733
# ,	O	2733	2734
# 4	O	2734	2735
# %	O	2736	2737
# по	O	2738	2740
# Российской	I-INST	2741	2751
# Федерации	I-INST	2752	2761
# и	O	2762	2763
# 11	O	2764	2766
# ,	O	2766	2767
# 9	O	2767	2768
# %	O	2769	2770
# по	O	2771	2773
# Сибирскому	I-INST	2774	2784
# федеральному	I-INST	2785	2797
# округу	I-INST	2798	2804
# )	O	2804	2805
# ,	O	2805	2806
# промышленность	I-ECO	2807	2821
# (	O	2822	2823
# 25	O	2823	2825
# ,	O	2825	2826
# 1	O	2826	2827
# %	O	2828	2829
# против	O	2830	2836
# 32	O	2837	2839
# ,	O	2839	2840
# 7	O	2840	2841
# %	O	2842	2843
# по	O	2844	2846
# Российской	I-INST	2847	2857
# Федерации	I-INST	2858	2867
# и	O	2868	2869
# 40	O	2870	2872
# ,	O	2872	2873
# 3	O	2873	2874
# %	O	2875	2876
# по	O	2877	2879
# Сибирскому	I-INST	2880	2890
# федеральному	I-INST	2891	2903
# округу	I-INST	2904	2910
# )	O	2910	2911
# ,	O	2911	2912
# сельское	I-ECO	2913	2921
# и	I-ECO	2922	2923
# лесное	I-ECO	2924	2930
# хозяйство	I-ECO	2931	2940
# (	O	2941	2942
# 18	O	2942	2944
# ,	O	2944	2945
# 2	O	2945	2946
# %	O	2947	2948
# ,	O	2948	2949
# что	O	2950	2953
# более	I-CMP	2954	2959
# чем	I-CMP	2960	2963
# в	I-CMP	2964	2965
# 4	I-CMP	2966	2967
# раза	I-CMP	2968	2972
# превосходит	I-CMP	2973	2984
# соответствующий	I-MET	2985	3000
# показатель	I-MET	3001	3011
# по	O	3012	3014
# Российской	I-INST	3015	3025
# Федерации	I-INST	3026	3035
# и	O	3036	3037
# почти	I-CMP	3038	3043
# в	I-CMP	3044	3045
# 3	I-CMP	3046	3047
# раза	I-CMP	3048	3052
# выше	I-CMP	3053	3057
# аналогичного	I-MET	3058	3070
# показателя	I-MET	3071	3081
# по	O	3082	3084
# Сибирскому	I-INST	3085	3095
# федеральному	I-INST	3096	3108
# округу	I-INST	3109	3115
# )	O	3115	3116
# .	O	3116	3117
#
# Существенно	I-CMP	3118	3129
# выше	I-CMP	3130	3134
# средне	I-MET	3135	3141
# российского	I-MET	3142	3153
# и	I-MET	3154	3155
# средне	I-MET	3156	3162
# окружного	I-MET	3163	3172
# показателей	I-MET	3173	3184
# удельный	B-MET	3185	3193
# вес	I-MET	3194	3197
# комплекса	I-MET	3198	3207
# отраслей	I-MET	3208	3216
# ,	I-MET	3216	3217
# относящихся	I-MET	3218	3229
# к	I-MET	3230	3231
# сфере	I-MET	3232	3237
# не	I-MET	3238	3240
# рыночных	I-MET	3241	3249
# услуг	I-MET	3250	3255
# (	O	3256	3257
# государственное	I-ACT	3257	3272
# управление	I-ACT	3273	3283
# и	I-ACT	3284	3285
# обеспечение	I-ACT	3286	3297
# безопасности	I-ACT	3298	3310
# ,	O	3310	3311
# здравоохранение	I-SOC	3312	3327
# и	O	3328	3329
# социальные	I-SOC	3330	3340
# услуги	I-SOC	3341	3347
# ,	O	3347	3348
# образование	I-SOC	3349	3360
# ,	O	3360	3361
# предоставление	I-SOC	3362	3376
# прочих	I-SOC	3377	3383
# коммунальных	I-SOC	3384	3396
# социальных	I-SOC	3397	3407
# и	I-SOC	3408	3409
# персональных	I-SOC	3410	3422
# услуг	I-SOC	3423	3428
# )	O	3428	3429
# ,	O	3429	3430
# составляющий	I-BIN	3431	3443
# 18	O	3444	3446
# ,	O	3446	3447
# 4	O	3447	3448
# %	O	3449	3450
# (	O	3451	3452
# при	O	3452	3455
# 13	O	3456	3458
# ,	O	3458	3459
# 3	O	3459	3460
# %	O	3461	3462
# по	O	3463	3465
# Российской	I-INST	3466	3476
# Федерации	I-INST	3477	3486
# и	O	3487	3488
# 15	O	3489	3491
# ,	O	3491	3492
# 0	O	3492	3493
# %	O	3494	3495
# по	O	3496	3498
# Сибирскому	I-INST	3499	3509
# федеральному	I-INST	3510	3522
# округу	I-INST	3523	3529
# )	O	3529	3530
# .	O	3530	3531
#
# Рис	O	3533	3536
# .	O	3536	3537
# 1	O	3538	3539
# .	O	3539	3540
#
# Структура	O	3541	3550
# ВРП	I-ECO	3551	3554
#
# КонсультантПлюс	O	3556	3571
# :	O	3571	3572
# примечание	O	3573	3583
# .	O	3583	3584
#
# Рисунок	O	3585	3592
# 1	O	3593	3594
# не	I-BIN	3595	3597
# приводится	I-BIN	3598	3608
# .	O	3608	3609
#
# В	O	3611	3612
# структуре	O	3613	3622
# валового	I-ECO	3623	3631
# регионального	I-ECO	3632	3645
# продукта	I-ECO	3646	3654
# увеличилась	I-CMP	3655	3666
# доля	I-MET	3667	3671
# реального	I-MET	3672	3681
# сектора	I-MET	3682	3689
# экономики	I-MET	3690	3699
# :	O	3699	3700
# сельского	I-ECO	3701	3710
# хозяйства	I-ECO	3711	3720
# -	O	3721	3722
# на	O	3723	3725
# 2	O	3726	3727
# ,	O	3727	3728
# 5	O	3728	3729
# процентных	O	3730	3740
# пункта	O	3741	3747
# ,	O	3747	3748
# строительства	I-ECO	3749	3762
# -	O	3763	3764
# на	O	3765	3767
# 0	O	3768	3769
# ,	O	3769	3770
# 6	O	3770	3771
# процентных	O	3772	3782
# пункта	O	3783	3789
# ,	O	3789	3790
# обрабатывающей	I-ECO	3791	3805
# промышленности	I-ECO	3806	3820
# -	O	3821	3822
# на	O	3823	3825
# 2	O	3826	3827
# ,	O	3827	3828
# 4	O	3828	3829
# процентных	O	3830	3840
# пункта	O	3841	3847
# ,	O	3847	3848
# при	O	3849	3852
# этом	O	3853	3857
# существенно	I-CMP	3858	3869
# сократилась	I-CMP	3870	3881
# доля	I-MET	3882	3886
# торговли	I-MET	3887	3895
# (	O	3896	3897
# на	O	3897	3899
# 4	O	3900	3901
# ,	O	3901	3902
# 9	O	3902	3903
# процентных	O	3904	3914
# пункта	O	3915	3921
# )	O	3921	3922
# .	O	3922	3923
#
# Основной	O	3924	3932
# вклад	O	3933	3938
# остается	O	3939	3947
# за	O	3948	3950
# обрабатывающим	I-ECO	3951	3965
# сектором	I-ECO	3966	3974
# промышленности	I-ECO	3975	3989
# .	O	3989	3990
#
# Социально	O	3991	4000
# -	O	4000	4001
# экономическое	O	4001	4014
# развитие	I-BIN	4015	4023
# Алтайского	I-INST	4024	4034
# края	I-INST	4035	4039
# в	O	4040	4041
# последнее	O	4042	4051
# десятилетие	O	4052	4063
# в	O	4064	4065
# различные	O	4066	4075
# годы	O	4076	4080
# имело	O	4081	4086
# ряд	O	4087	4090
# ярко	I-QUA	4091	4095
# выраженных	I-QUA	4096	4106
# тенденций	O	4107	4116
# .	O	4116	4117
#
# Начиная	O	4118	4125
# с	O	4126	4127
# 2000	O	4128	4132
# года	O	4133	4137
# ,	O	4137	4138
# экономика	I-ECO	4139	4148
# Алтайского	I-INST	4149	4159
# края	I-INST	4160	4164
# характеризовалась	O	4165	4182
# устойчивым	I-QUA	4183	4193
# экономическим	I-MET	4194	4207
# ростом	I-MET	4208	4214
# .	O	4214	4215
#
# Причем	O	4216	4222
# рост	I-QUA	4223	4227
# происходил	I-BIN	4228	4238
# по	I-CMP	4239	4241
# возрастающей	I-CMP	4242	4254
# .	O	4254	4255
#
# В	O	4256	4257
# последние	O	4258	4267
# два	O	4268	4271
# года	O	4272	4276
# накануне	O	4277	4285
# экономического	I-ECO	4286	4300
# кризиса	I-ECO	4301	4308
# экономический	I-MET	4309	4322
# рост	I-MET	4323	4327
# достиг	I-BIN	4328	4334
# максимального	I-MET	4335	4348
# уровня	I-MET	4349	4355
# -	O	4356	4357
# средне	I-MET	4358	4364
# годовой	I-MET	4365	4372
# прирост	I-MET	4373	4380
# ВРП	I-MET	4381	4384
# составил	O	4385	4393
# примерно	O	4394	4402
# 10	O	4403	4405
# %	O	4406	4407
# .	O	4407	4408
#
# За	O	4409	4411
# 2006	O	4412	4416
# -	O	4417	4418
# 2007	O	4419	4423
# годы	O	4424	4428
# производство	I-MET	4429	4441
# валового	I-MET	4442	4450
# регионального	I-MET	4451	4464
# продукта	I-MET	4465	4473
# в	O	4474	4475
# крае	O	4476	4480
# выросло	I-CMP	4481	4488
# на	O	4489	4491
# 20	O	4492	4494
# ,	O	4494	4495
# 7	O	4495	4496
# %	O	4497	4498
# (	O	4499	4500
# по	O	4500	4502
# Российской	I-INST	4503	4513
# Федерации	I-INST	4514	4523
# -	O	4524	4525
# на	O	4526	4528
# 17	O	4529	4531
# ,	O	4531	4532
# 3	O	4532	4533
# %	O	4534	4535
# ,	O	4535	4536
# в	O	4537	4538
# среднем	O	4539	4546
# по	O	4547	4549
# Сибирскому	I-INST	4550	4560
# федеральному	I-INST	4561	4573
# округу	I-INST	4574	4580
# -	O	4581	4582
# на	O	4583	4585
# 14	O	4586	4588
# ,	O	4588	4589
# 2	O	4589	4590
# %	O	4591	4592
# )	O	4592	4593
# .	O	4593	4594
#
# Алтайский	I-INST	4595	4604
# край	I-INST	4605	4609
# являлся	O	4610	4617
# одним	O	4618	4623
# из	O	4624	4626
# динамично	I-QUA	4627	4636
# развивающихся	I-CMP	4637	4650
# регионов	I-INST	4651	4659
# России	I-INST	4660	4666
# .	O	4666	4667
#
# В	O	4668	4669
# результате	O	4670	4680
# укрепления	I-CMP	4681	4691
# позиций	O	4692	4699
# традиционных	I-ECO	4700	4712
# базовых	I-ECO	4713	4720
# секторов	I-ECO	4721	4729
# экономики	I-ECO	4730	4739
# региона	I-ECO	4740	4747
# были	O	4748	4752
# достигнуты	I-BIN	4753	4763
# опережающие	I-QUA	4764	4775
# темпы	I-MET	4776	4781
# роста	I-MET	4782	4787
# практически	O	4788	4799
# по	O	4800	4802
# всем	O	4803	4807
# макроэкономическим	I-ECO	4808	4826
# показателям	I-ECO	4827	4838
# (	O	4839	4840
# рис	O	4840	4843
# .	O	4843	4844
# 2	O	4845	4846
# )	O	4846	4847
# .	O	4847	4848
#
# Инвестиции	I-MET	4849	4859
# в	I-MET	4860	4861
# основной	I-MET	4862	4870
# капитал	I-MET	4871	4878
# за	O	4879	4881
# два	O	4882	4885
# года	O	4886	4890
# увеличились	I-CMP	4891	4902
# более	B-CMP	4903	4908
# чем	I-CMP	4909	4912
# в	I-CMP	4913	4914
# 1	I-CMP	4915	4916
# ,	I-CMP	4916	4917
# 5	I-CMP	4917	4918
# раза	I-CMP	4919	4923
# .	O	4923	4924
#
# Сфера	I-ECO	4925	4930
# торговли	I-ECO	4931	4939
# и	I-ECO	4940	4941
# услуг	I-ECO	4942	4947
# превратилась	O	4948	4960
# в	O	4961	4962
# одну	O	4963	4967
# из	O	4968	4970
# самых	I-CMP	4971	4976
# динамично	I-CMP	4977	4986
# развивающихся	I-CMP	4987	5000
# отраслей	O	5001	5009
# края	O	5010	5014
# .	O	5014	5015
#
# Опережающими	I-CMP	5016	5028
# темпами	I-CMP	5029	5036
# по	O	5037	5039
# сравнению	O	5040	5049
# со	O	5050	5052
# средне	O	5053	5059
# российскими	O	5060	5071
# увеличивались	I-CMP	5072	5085
# денежные	I-ECO	5086	5094
# доходы	I-ECO	5095	5101
# населения	I-ECO	5102	5111
# и	O	5112	5113
# заработная	I-ECO	5114	5124
# плата	I-ECO	5125	5130
# ,	O	5130	5131
# уровень	I-SOC	5132	5139
# безработицы	I-SOC	5140	5151
# в	O	5152	5153
# 2007	O	5154	5158
# году	O	5159	5163
# достиг	I-BIN	5164	5170
# минимального	I-QUA	5171	5183
# значения	O	5184	5192
# за	O	5193	5195
# период	O	5196	5202
# с	O	5203	5204
# начала	O	5205	5211
# 90	O	5212	5214
# -	O	5214	5215
# х	O	5215	5216
# годов	O	5217	5222
# .	O	5222	5223
#
# Рис	O	5225	5228
# .	O	5228	5229
# 2	O	5230	5231
# .	O	5231	5232
#
# Темпы	O	5233	5238
# прироста	I-CMP	5239	5247
# основных	I-MET	5248	5256
# показателей	I-MET	5257	5268
#
# Алтайского	I-INST	5269	5279
# края	I-INST	5280	5284
# ,	O	5284	5285
# Сибирского	I-INST	5286	5296
# федерального	I-INST	5297	5309
# округа	I-INST	5310	5316
#
# и	O	5317	5318
# Российской	I-INST	5319	5329
# Федерации	I-INST	5330	5339
# в	O	5340	5341
# 2006	O	5342	5346
# -	O	5347	5348
# 2007	O	5349	5353
# годах	O	5354	5359
# ,	O	5359	5360
# %	O	5361	5362
#
# КонсультантПлюс	O	5364	5379
# :	O	5379	5380
# примечание	O	5381	5391
# .	O	5391	5392
#
# Рисунок	O	5393	5400
# 2	O	5401	5402
# не	I-BIN	5403	5405
# приводится	I-BIN	5406	5416
# .	O	5416	5417
#
# Комплекс	I-ACT	5419	5427
# целевых	I-ACT	5428	5435
# мер	I-ACT	5436	5439
# исполнительной	I-ACT	5440	5454
# и	I-ACT	5455	5456
# законодательной	I-ACT	5457	5472
# ветвей	I-ACT	5473	5479
# власти	I-ACT	5480	5486
# Алтайского	I-ACT	5487	5497
# края	I-ACT	5498	5502
# ,	O	5502	5503
# реализованных	I-BIN	5504	5517
# в	O	5518	5519
# 2006	O	5520	5524
# -	O	5525	5526
# 2007	O	5527	5531
# годах	O	5532	5537
# ,	O	5537	5538
# способствовал	I-BIN	5539	5552
# качественному	I-QUA	5553	5566
# преобразованию	I-CMP	5567	5581
# экономики	I-ECO	5582	5591
# региона	I-ECO	5592	5599
# на	O	5600	5602
# основе	O	5603	5609
# технологической	O	5610	5625
# модернизации	I-BIN	5626	5638
# производства	O	5639	5651
# ,	O	5651	5652
# повышения	I-CMP	5653	5662
# конкурентоспособности	I-MET	5663	5684
# выпускаемой	I-MET	5685	5696
# продукции	I-MET	5697	5706
# ,	O	5706	5707
# роста	I-CMP	5708	5713
# инновационной	I-ECO	5714	5727
# продукции	I-ECO	5728	5737
# ,	O	5737	5738
# развития	I-CMP	5739	5747
# кадрового	I-SOC	5748	5757
# потенциала	I-SOC	5758	5768
# ,	O	5768	5769
# повышения	I-CMP	5770	5779
# уровня	I-MET	5780	5786
# и	I-MET	5787	5788
# качества	I-MET	5789	5797
# жизни	I-MET	5798	5803
# населения	I-MET	5804	5813
# края	I-MET	5814	5818
# .	O	5818	5819
#
# Влияние	O	5820	5827
# мирового	I-ECO	5828	5836
# финансового	I-ECO	5837	5848
# кризиса	I-ECO	5849	5856
# (	O	5857	5858
# 2008	O	5858	5862
# -	O	5863	5864
# 2009	O	5865	5869
# годы	O	5870	5874
# )	O	5874	5875
# нарушило	I-BIN	5876	5884
# тенденцию	I-ECO	5885	5894
# ускоренного	I-ECO	5895	5906
# экономического	I-ECO	5907	5921
# роста	I-ECO	5922	5927
# в	I-ECO	5928	5929
# регионе	I-ECO	5930	5937
# и	O	5938	5939
# соответственно	O	5940	5954
# отразилось	I-BIN	5955	5965
# на	O	5966	5968
# основных	I-MET	5969	5977
# социально	I-MET	5978	5987
# -	I-MET	5987	5988
# экономических	I-MET	5988	6001
# показателях	I-MET	6002	6013
# :	O	6013	6014
# объемах	I-MET	6015	6022
# производства	I-MET	6023	6035
# промышленной	I-MET	6036	6048
# продукции	I-MET	6049	6058
# и	I-MET	6059	6060
# строительных	I-MET	6061	6073
# работ	I-MET	6074	6079
# ,	O	6079	6080
# показателях	I-MET	6081	6092
# потребительского	I-MET	6093	6109
# рынка	I-MET	6110	6115
# ,	I-MET	6115	6116
# рынка	I-MET	6117	6122
# труда	I-MET	6123	6128
# и	I-MET	6129	6130
# занятости	I-MET	6131	6140
# населения	I-MET	6141	6150
# ,	O	6150	6151
# а	O	6152	6153
# также	O	6154	6159
# на	O	6160	6162
# уровне	I-MET	6163	6169
# жизни	I-MET	6170	6175
# населения	I-MET	6176	6185
# .	O	6185	6186
#
# Вместе	O	6187	6193
# с	O	6194	6195
# тем	O	6196	6199
# на	O	6200	6202
# фоне	O	6203	6207
# показателей	I-MET	6208	6219
# ,	O	6219	6220
# сложившихся	O	6221	6232
# в	O	6233	6234
# целом	O	6235	6240
# по	O	6241	6243
# Российской	I-INST	6244	6254
# Федерации	I-INST	6255	6264
# и	O	6265	6266
# по	O	6267	6269
# Сибирскому	I-INST	6270	6280
# федеральному	I-INST	6281	6293
# округу	I-INST	6294	6300
# ,	O	6300	6301
# в	O	6302	6303
# Алтайском	I-INST	6304	6313
# крае	I-INST	6314	6318
# снижение	I-CMP	6319	6327
# отдельных	I-MET	6328	6337
# показателей	I-MET	6338	6349
# было	O	6350	6354
# менее	I-CMP	6355	6360
# значительным	I-CMP	6361	6373
# (	O	6374	6375
# табл	O	6375	6379
# .	O	6379	6380
# 1	O	6381	6382
# )	O	6382	6383
# .	O	6383	6384
#
# Производственный	I-ECO	6385	6401
# комплекс	I-ECO	6402	6410
# Алтайского	I-ECO	6411	6421
# края	I-ECO	6422	6426
# оказался	O	6427	6435
# более	I-CMP	6436	6441
# устойчивым	I-CMP	6442	6452
# к	O	6453	6454
# кризису	I-ECO	6455	6462
# ,	O	6462	6463
# чем	O	6464	6467
# большинство	I-CMP	6468	6479
# российских	I-INST	6480	6490
# регионов	I-INST	6491	6499
# ,	O	6499	6500
# спад	I-CMP	6501	6505
# ВРП	I-MET	6506	6509
# и	O	6510	6511
# объемов	I-MET	6512	6519
# промышленного	I-MET	6520	6533
# производства	I-MET	6534	6546
# был	O	6547	6550
# ниже	I-CMP	6551	6555
# средних	I-MET	6556	6563
# по	I-MET	6564	6566
# стране	I-MET	6567	6573
# показателей	I-MET	6574	6585
# .	O	6585	6586
#
# Из	O	6587	6589
# видов	I-ECO	6590	6595
# деятельности	I-ECO	6596	6608
# промышленных	I-ECO	6609	6621
# отраслей	I-ECO	6622	6630
# производство	B-ECO	6631	6643
# пищевых	I-ECO	6644	6651
# продуктов	I-ECO	6652	6661
# характеризовалось	O	6662	6679
# в	O	6680	6681
# 2009	O	6682	6686
# году	O	6687	6691
# положительной	I-CMP	6692	6705
# динамикой	I-CMP	6706	6715
# -	O	6716	6717
# 115	O	6718	6721
# ,	O	6721	6722
# 8	O	6722	6723
# %	O	6724	6725
# ,	O	6725	6726
# сельское	I-ECO	6727	6735
# хозяйство	I-ECO	6736	6745
# края	I-ECO	6746	6750
# также	O	6751	6756
# продемонстрировало	O	6757	6775
# существенный	I-CMP	6776	6788
# рост	I-CMP	6789	6793
# -	O	6794	6795
# 120	O	6796	6799
# %	O	6800	6801
# к	O	6802	6803
# уровню	I-MET	6804	6810
# предыдущего	I-MET	6811	6822
# года	I-MET	6823	6827
# .	O	6827	6828
#
# Таблица	O	6830	6837
# 1	O	6838	6839
#
# Динамика	O	6841	6849
#
# основных	I-MET	6850	6858
# показателей	I-MET	6859	6870
# социально	I-MET	6871	6880
# -	I-MET	6880	6881
# экономического	I-MET	6881	6895
# развития	I-MET	6896	6904
#
# Алтайского	I-INST	6905	6915
# края	I-INST	6916	6920
# ,	O	6920	6921
# Российской	I-INST	6922	6932
# Федерации	I-INST	6933	6942
# и	O	6943	6944
#
# Сибирского	I-INST	6945	6955
# федерального	I-INST	6956	6968
# округа	I-INST	6969	6975
# в	O	6976	6977
# 2008	O	6978	6982
# -	O	6983	6984
# 2011	O	6985	6989
# гг	O	6990	6992
# .	O	6992	6993
#
# Данная	O	6995	7001
# ситуация	O	7002	7010
# позволила	I-BIN	7011	7020
# сделать	O	7021	7028
# вывод	O	7029	7034
# о	O	7035	7036
# том	O	7037	7040
# ,	O	7040	7041
# что	O	7042	7045
# агропромышленный	I-ECO	7046	7062
# комплекс	I-ECO	7063	7071
# Алтайского	I-ECO	7072	7082
# края	I-ECO	7083	7087
# ,	O	7087	7088
# занимая	O	7089	7096
# существенную	I-CMP	7097	7109
# долю	I-MET	7110	7114
# в	I-MET	7115	7116
# структуре	I-MET	7117	7126
# производства	I-MET	7127	7139
# продукции	I-MET	7140	7149
# и	I-MET	7150	7151
# занятости	I-MET	7152	7161
# населения	I-MET	7162	7171
# ,	O	7171	7172
# подтвердил	I-BIN	7173	7183
# свою	O	7184	7188
# жизнеспособность	O	7189	7205
# в	O	7206	7207
# условиях	I-ECO	7208	7216
# кризиса	I-ECO	7217	7224
# и	O	7225	7226
# может	O	7227	7232
# с	O	7233	7234
# определенной	O	7235	7247
# степенью	I-MET	7248	7256
# надежности	I-MET	7257	7267
# обеспечить	O	7268	7278
# в	O	7279	7280
# стратегической	O	7281	7295
# перспективе	O	7296	7307
# устойчивость	O	7308	7320
# региональной	I-ECO	7321	7333
# экономики	I-ECO	7334	7343
# .	O	7343	7344
#
# В	O	7345	7346
# 2009	O	7347	7351
# -	O	7352	7353
# 2010	O	7354	7358
# годах	O	7359	7364
# в	O	7365	7366
# крае	O	7367	7371
# была	I-BIN	7372	7376
# проведена	I-BIN	7377	7386
# масштабная	I-QUA	7387	7397
# работа	I-ACT	7398	7404
# по	I-ACT	7405	7407
# стабилизации	I-ACT	7408	7420
# экономической	I-ACT	7421	7434
# ситуации	I-ACT	7435	7443
# ,	O	7443	7444
# осуществлен	I-BIN	7445	7456
# комплекс	I-ACT	7457	7465
# антикризисных	I-ACT	7466	7479
# мероприятий	I-ACT	7480	7491
# .	O	7491	7492
#
# В	O	7493	7494
# результате	O	7495	7505
# в	O	7506	7507
# 2010	O	7508	7512
# году	O	7513	7517
# темпы	I-MET	7518	7523
# восстановления	I-MET	7524	7538
# алтайской	I-MET	7539	7548
# экономики	I-MET	7549	7558
# оказались	I-BIN	7559	7568
# значительно	I-QUA	7569	7580
# выше	I-CMP	7581	7585
# ,	O	7585	7586
# чем	O	7587	7590
# в	O	7591	7592
# Российской	I-INST	7593	7603
# Федерации	I-INST	7604	7613
# и	O	7614	7615
# в	O	7616	7617
# Сибирском	I-INST	7618	7627
# федеральном	I-INST	7628	7639
# округе	I-INST	7640	7646
# .	O	7646	7647
#
# С	O	7648	7649
# 2010	O	7650	7654
# года	O	7655	7659
# на	O	7660	7662
# экономическую	I-MET	7663	7676
# динамику	I-MET	7677	7685
# Алтайского	I-MET	7686	7696
# края	I-MET	7697	7701
# стало	O	7702	7707
# усиливаться	I-CMP	7708	7719
# воздействие	O	7720	7731
# благоприятных	I-CMP	7732	7745
# факторов	I-MET	7746	7754
# территориального	I-MET	7755	7771
# развития	I-MET	7772	7780
# макроэкономического	I-MET	7781	7800
# ,	I-MET	7800	7801
# геостратегического	I-MET	7802	7820
# и	I-MET	7821	7822
# конъюнктурного	I-MET	7823	7837
# характера	I-MET	7838	7847
# .	O	7847	7848
#
# Алтайский	I-INST	7849	7858
# край	I-INST	7859	7863
# в	O	7864	7865
# 2010	O	7866	7870
# году	O	7871	7875
# вновь	O	7876	7881
# занял	I-BIN	7882	7887
# лидирующие	I-QUA	7888	7898
# позиции	I-QUA	7899	7906
# в	O	7907	7908
# Российской	I-INST	7909	7919
# Федерации	I-INST	7920	7929
# и	O	7930	7931
# Сибирском	I-INST	7932	7941
# федеральном	I-INST	7942	7953
# округе	I-INST	7954	7960
# по	O	7961	7963
# темпам	I-MET	7964	7970
# роста	I-MET	7971	7976
# основных	I-MET	7977	7985
# показателей	I-MET	7986	7997
# социально	I-MET	7998	8007
# -	I-MET	8007	8008
# экономического	I-MET	8008	8022
# развития	I-MET	8023	8031
# .	O	8031	8032
#
# Активное	O	8033	8041
# восстановление	I-ACT	8042	8056
# экономики	I-ACT	8057	8066
# региона	I-ACT	8067	8074
# позволило	I-BIN	8075	8084
# Алтайскому	I-INST	8085	8095
# краю	I-INST	8096	8100
# значительно	O	8101	8112
# превзойти	I-CMP	8113	8122
# аналогичные	I-MET	8123	8134
# показатели	I-MET	8135	8145
# Российской	I-INST	8146	8156
# Федерации	I-INST	8157	8166
# и	O	8167	8168
# Сибирского	I-INST	8169	8179
# федерального	I-INST	8180	8192
# округа	I-INST	8193	8199
# по	O	8200	8202
# индексу	I-MET	8203	8210
# промышленного	I-MET	8211	8224
# производства	I-MET	8225	8237
# ,	O	8237	8238
# индексам	I-MET	8239	8247
# физического	I-MET	8248	8259
# объема	I-MET	8260	8266
# продукции	I-MET	8267	8276
# сельского	I-MET	8277	8286
# хозяйства	I-MET	8287	8296
# ,	I-MET	8296	8297
# инвестиций	I-MET	8298	8308
# ,	I-MET	8308	8309
# оборота	I-MET	8310	8317
# розничной	I-MET	8318	8327
# торговли	I-MET	8328	8336
# и	I-MET	8337	8338
# виду	I-MET	8339	8343
# деятельности	I-MET	8344	8356
# "	I-MET	8357	8358
# Строительство	I-MET	8358	8371
# "	I-MET	8371	8372
# (	O	8373	8374
# табл	O	8374	8378
# .	O	8378	8379
# 1	O	8380	8381
# )	O	8381	8382
# .	O	8382	8383
#
# Социально	O	8384	8393
# -	O	8393	8394
# экономическое	O	8394	8407
# развитие	I-BIN	8408	8416
# Алтайского	I-INST	8417	8427
# края	I-INST	8428	8432
# в	O	8433	8434
# 2011	O	8435	8439
# году	O	8440	8444
# свидетельствует	I-BIN	8445	8460
# о	O	8461	8462
# закреплении	O	8463	8474
# положительных	I-CMP	8475	8488
# тенденций	I-CMP	8489	8498
# развития	I-BIN	8499	8507
# региона	O	8508	8515
# ,	O	8515	8516
# создания	O	8517	8525
# базы	O	8526	8530
# для	O	8531	8534
# развития	I-BIN	8535	8543
# экономики	I-ECO	8544	8553
# в	O	8554	8555
# последующие	O	8556	8567
# годы	O	8568	8572
# .	O	8572	8573
#
# В	I-CMP	8574	8575
# наибольшей	I-CMP	8576	8586
# степени	I-CMP	8587	8594
# рост	B-CMP	8595	8599
# сконцентрирован	O	8600	8615
# в	O	8616	8617
# сфере	I-ECO	8618	8623
# промышленного	I-ECO	8624	8637
# производства	I-ECO	8638	8650
# .	O	8650	8651
#
# Алтайский	I-INST	8652	8661
# край	I-INST	8662	8666
# лидирует	I-BIN	8667	8675
# среди	O	8676	8681
# субъектов	I-INST	8682	8691
# Сибирского	I-INST	8692	8702
# федерального	I-INST	8703	8715
# округа	I-INST	8716	8722
# по	O	8723	8725
# динамике	I-MET	8726	8734
# индексов	I-MET	8735	8743
# промышленного	I-MET	8744	8757
# производства	I-MET	8758	8770
# в	O	8771	8772
# производстве	I-ECO	8773	8785
# пищевых	I-ECO	8786	8793
# продуктов	I-ECO	8794	8803
# ,	O	8803	8804
# текстильном	I-ECO	8805	8816
# и	I-ECO	8817	8818
# швейном	I-ECO	8819	8826
# производстве	I-ECO	8827	8839
# ,	O	8839	8840
# производстве	I-ECO	8841	8853
# кокса	I-ECO	8854	8859
# и	I-ECO	8860	8861
# нефтепродуктов	I-ECO	8862	8876
# ,	O	8876	8877
# химическом	I-ECO	8878	8888
# производстве	I-ECO	8889	8901
# ,	O	8901	8902
# в	O	8903	8904
# обработке	I-ECO	8905	8914
# древесины	I-ECO	8915	8924
# и	O	8925	8926
# производстве	I-ECO	8927	8939
# изделий	I-ECO	8940	8947
# из	I-ECO	8948	8950
# дерева	I-ECO	8951	8957
# .	O	8957	8958
#
# Объем	I-MET	8959	8964
# работ	I-MET	8965	8970
# по	I-MET	8971	8973
# виду	I-MET	8974	8978
# деятельности	I-MET	8979	8991
# "	I-MET	8992	8993
# Строительство	I-MET	8993	9006
# "	I-MET	9006	9007
# увеличился	I-CMP	9008	9018
# на	O	9019	9021
# 28	O	9022	9024
# %	O	9025	9026
# (	O	9027	9028
# это	O	9028	9031
# 2	O	9032	9033
# место	O	9034	9039
# в	O	9040	9041
# Сибирском	I-INST	9042	9051
# федеральном	I-INST	9052	9063
# округе	I-INST	9064	9070
# и	O	9071	9072
# 9	O	9073	9074
# место	O	9075	9080
# в	O	9081	9082
# России	I-INST	9083	9089
# )	O	9089	9090
# .	O	9090	9091
#
# По	O	9092	9094
# темпам	I-MET	9095	9101
# роста	I-MET	9102	9107
# грузооборота	I-MET	9108	9120
# ,	O	9120	9121
# соответственно	O	9122	9136
# ,	O	9136	9137
# 4	O	9138	9139
# место	O	9140	9145
# и	O	9146	9147
# 28	O	9148	9150
# место	O	9151	9156
# .	O	9156	9157
#
# Объем	I-MET	9158	9163
# оборота	I-MET	9164	9171
# розничной	I-MET	9172	9181
# торговли	I-MET	9182	9190
# увеличился	I-CMP	9191	9201
# в	O	9202	9203
# крае	O	9204	9208
# в	O	9209	9210
# 2011	O	9211	9215
# году	O	9216	9220
# на	O	9221	9223
# 13	O	9224	9226
# %	O	9227	9228
# ,	O	9228	9229
# что	O	9230	9233
# почти	I-CMP	9234	9239
# в	I-CMP	9240	9241
# 2	I-CMP	9242	9243
# раза	I-CMP	9244	9248
# выше	I-CMP	9249	9253
# соответствующего	I-MET	9254	9270
# средне	I-MET	9271	9277
# российского	I-MET	9278	9289
# показателя	I-MET	9290	9300
# (	O	9301	9302
# 107	O	9302	9305
# ,	O	9305	9306
# 2	O	9306	9307
# %	O	9308	9309
# )	O	9309	9310
# и	O	9311	9312
# среднего	I-MET	9313	9321
# показателя	I-MET	9322	9332
# по	I-MET	9333	9335
# Сибирскому	I-MET	9336	9346
# федеральному	I-MET	9347	9359
# округу	I-MET	9360	9366
# (	O	9367	9368
# 107	O	9368	9371
# ,	O	9371	9372
# 9	O	9372	9373
# %	O	9374	9375
# )	O	9375	9376
# .	O	9376	9377
#
# Данный	I-MET	9378	9384
# показатель	I-MET	9385	9395
# соответствует	I-BIN	9396	9409
# 9	O	9410	9411
# месту	O	9412	9417
# в	O	9418	9419
# рейтинге	O	9420	9428
# регионов	I-INST	9429	9437
# Российской	I-INST	9438	9448
# Федерации	I-INST	9449	9458
# и	O	9459	9460
# 2	O	9461	9462
# -	O	9463	9464
# в	O	9465	9466
# Сибирском	I-INST	9467	9476
# федеральном	I-INST	9477	9488
# округе	I-INST	9489	9495
# .	O	9495	9496
#
# В	O	9497	9498
# 2011	O	9499	9503
# году	O	9504	9508
# сохранилась	I-BIN	9509	9520
# высокая	I-QUA	9521	9528
# инвестиционная	I-MET	9529	9543
# активность	I-MET	9544	9554
# Алтайского	I-MET	9555	9565
# края	I-MET	9566	9570
# .	O	9570	9571
#
# Прирост	I-MET	9572	9579
# инвестиций	I-MET	9580	9590
# в	I-MET	9591	9592
# основной	I-MET	9593	9601
# капитал	I-MET	9602	9609
# по	O	9610	9612
# Алтайскому	I-INST	9613	9623
# краю	I-INST	9624	9628
# составил	O	9629	9637
# 15	O	9638	9640
# ,	O	9640	9641
# 4	O	9641	9642
# %	O	9643	9644
# ,	O	9644	9645
# что	O	9646	9649
# существенно	I-CMP	9650	9661
# выше	I-CMP	9662	9666
# ,	O	9666	9667
# чем	O	9668	9671
# в	O	9672	9673
# Российской	I-INST	9674	9684
# Федерации	I-INST	9685	9694
# (	O	9695	9696
# 8	O	9696	9697
# ,	O	9697	9698
# 3	O	9698	9699
# %	O	9700	9701
# )	O	9701	9702
# и	O	9703	9704
# соответствует	I-BIN	9705	9718
# приросту	I-CMP	9719	9727
# в	O	9728	9729
# Сибирском	I-INST	9730	9739
# федеральном	I-INST	9740	9751
# округе	I-INST	9752	9758
# (	O	9759	9760
# 16	O	9760	9762
# %	O	9763	9764
# )	O	9764	9765
# .	O	9765	9766
#
# В	O	9767	9768
# основной	I-ECO	9769	9777
# капитал	I-ECO	9778	9785
# края	I-ECO	9786	9790
# инвестировано	I-BIN	9791	9804
# 70	O	9805	9807
# ,	O	9807	9808
# 8	O	9808	9809
# млрд	O	9810	9814
# .	O	9814	9815
# рублей	O	9816	9822
# .	O	9822	9823
#
# За	O	9824	9826
# десяти	O	9827	9833
# летний	O	9834	9840
# период	O	9841	9847
# 2001	O	9848	9852
# -	O	9853	9854
# 2011	O	9855	9859
# годов	O	9860	9865
# объем	I-MET	9866	9871
# инвестиций	I-MET	9872	9882
# в	I-MET	9883	9884
# основной	I-MET	9885	9893
# капитал	I-MET	9894	9901
# края	I-MET	9902	9906
# в	O	9907	9908
# сопоставимых	O	9909	9921
# ценах	O	9922	9927
# вырос	I-CMP	9928	9933
# более	I-CMP	9934	9939
# чем	I-CMP	9940	9943
# в	I-CMP	9944	9945
# 3	I-CMP	9946	9947
# раза	I-CMP	9948	9952
# (	O	9953	9954
# по	O	9954	9956
# России	I-INST	9957	9963
# -	O	9964	9965
# в	O	9966	9967
# 2	O	9968	9969
# ,	O	9969	9970
# 4	O	9970	9971
# раза	O	9972	9976
# )	O	9976	9977
# ,	O	9977	9978
# средне	I-MET	9979	9985
# годовой	I-MET	9986	9993
# темп	I-MET	9994	9998
# прироста	I-MET	9999	10007
# составил	O	10008	10016
# 11	O	10017	10019
# ,	O	10019	10020
# 6	O	10020	10021
# %	O	10022	10023
# (	O	10024	10025
# Россия	I-INST	10025	10031
# -	O	10032	10033
# 8	O	10034	10035
# ,	O	10035	10036
# 9	O	10036	10037
# %	O	10038	10039
# )	O	10039	10040
# (	O	10041	10042
# рис	O	10042	10045
# .	O	10045	10046
# 3	O	10047	10048
# )	O	10048	10049
# .	O	10049	10050
#
# Рис	O	10052	10055
# .	O	10055	10056
# 3	O	10057	10058
# .	O	10058	10059
#
# Инвестиции	I-ECO	10060	10070
# в	I-ECO	10071	10072
# основной	I-ECO	10073	10081
# капитал	I-ECO	10082	10089
#
# (	O	10090	10091
# в	O	10091	10092
# сопоставимых	O	10093	10105
# ценах	O	10106	10111
# ,	O	10111	10112
# в	O	10113	10114
# %	O	10115	10116
# к	O	10117	10118
# предыдущему	O	10119	10130
# году	O	10131	10135
# )	O	10135	10136
#
# КонсультантПлюс	O	10138	10153
# :	O	10153	10154
# примечание	O	10155	10165
# .	O	10165	10166
#
# Рисунок	O	10167	10174
# 3	O	10175	10176
# не	I-BIN	10177	10179
# приводится	I-BIN	10180	10190
# .	O	10190	10191
#
# Вклад	I-MET	10193	10198
# краевого	I-MET	10199	10207
# бюджета	I-MET	10208	10215
# в	I-MET	10216	10217
# объем	I-MET	10218	10223
# инвестиций	I-MET	10224	10234
# в	O	10235	10236
# 2011	O	10237	10241
# году	O	10242	10246
# составил	O	10247	10255
# 11	O	10256	10258
# ,	O	10258	10259
# 1	O	10259	10260
# %	O	10261	10262
# ,	O	10262	10263
# что	O	10264	10267
# больше	I-CMP	10268	10274
# ,	O	10274	10275
# чем	O	10276	10279
# в	O	10280	10281
# среднем	O	10282	10289
# по	O	10290	10292
# Российской	I-INST	10293	10303
# Федерации	I-INST	10304	10313
# (	O	10314	10315
# 7	O	10315	10316
# ,	O	10316	10317
# 9	O	10317	10318
# %	O	10319	10320
# )	O	10320	10321
# и	O	10322	10323
# Сибирскому	I-INST	10324	10334
# федеральному	I-INST	10335	10347
# округу	I-INST	10348	10354
# (	O	10355	10356
# 5	O	10356	10357
# ,	O	10357	10358
# 6	O	10358	10359
# %	O	10360	10361
# )	O	10361	10362
# .	O	10362	10363
#
# Роль	O	10364	10368
# кредитов	I-ECO	10369	10377
# банков	I-ECO	10378	10384
# в	O	10385	10386
# современном	I-ECO	10387	10398
# инвестиционном	I-ECO	10399	10413
# процессе	I-ECO	10414	10422
# в	O	10423	10424
# регионе	O	10425	10432
# достаточно	I-QUA	10433	10443
# ощутима	I-BIN	10444	10451
# :	O	10451	10452
# на	O	10453	10455
# их	O	10456	10458
# долю	O	10459	10463
# в	O	10464	10465
# источниках	I-ECO	10466	10476
# финансирования	I-ECO	10477	10491
# инвестиций	I-ECO	10492	10502
# в	O	10503	10504
# 2011	O	10505	10509
# году	O	10510	10514
# пришлось	O	10515	10523
# 15	O	10524	10526
# ,	O	10526	10527
# 4	O	10527	10528
# %	O	10529	10530
# ,	O	10530	10531
# что	O	10532	10535
# выше	I-CMP	10536	10540
# соответствующего	I-CMP	10541	10557
# показателя	I-CMP	10558	10568
# как	O	10569	10572
# по	O	10573	10575
# Российской	I-INST	10576	10586
# Федерации	I-INST	10587	10596
# в	O	10597	10598
# целом	O	10599	10604
# (	O	10605	10606
# 7	O	10606	10607
# ,	O	10607	10608
# 7	O	10608	10609
# %	O	10610	10611
# )	O	10611	10612
# ,	O	10612	10613
# так	O	10614	10617
# и	O	10618	10619
# по	O	10620	10622
# Сибирскому	I-INST	10623	10633
# федеральному	I-INST	10634	10646
# округу	I-INST	10647	10653
# (	O	10654	10655
# 6	O	10655	10656
# ,	O	10656	10657
# 6	O	10657	10658
# %	O	10659	10660
# )	O	10660	10661
# .	O	10661	10662
#
# Алтайский	I-INST	10663	10672
# край	I-INST	10673	10677
# стабильно	I-QUA	10678	10687
# входит	I-BIN	10688	10694
# в	O	10695	10696
# тройку	O	10697	10703
# лидеров	O	10704	10711
# Сибирского	I-INST	10712	10722
# федерального	I-INST	10723	10735
# округа	I-INST	10736	10742
# и	O	10743	10744
# в	O	10745	10746
# двадцатку	O	10747	10756
# ведущих	O	10757	10764
# регионов	I-INST	10765	10773
# России	I-INST	10774	10780
# по	O	10781	10783
# количеству	I-MET	10784	10794
# малых	I-MET	10795	10800
# предприятий	I-MET	10801	10812
# .	O	10812	10813
#
# В	O	10814	10815
# регионе	O	10816	10823
# малые	I-ECO	10824	10829
# предприятия	I-ECO	10830	10841
# выполняют	I-BIN	10842	10851
# более	I-CMP	10852	10857
# 65	I-CMP	10858	10860
# %	I-CMP	10861	10862
# всего	O	10863	10868
# объема	I-MET	10869	10875
# строительных	I-MET	10876	10888
# работ	I-MET	10889	10894
# ,	O	10894	10895
# формируют	I-BIN	10896	10905
# почти	O	10906	10911
# 22	O	10912	10914
# %	O	10915	10916
# общего	I-MET	10917	10923
# объема	I-MET	10924	10930
# отгруженных	I-MET	10931	10942
# товаров	I-MET	10943	10950
# обрабатывающих	I-MET	10951	10965
# производств	I-MET	10966	10977
# ,	O	10977	10978
# 17	O	10979	10981
# %	O	10982	10983
# оборота	I-MET	10984	10991
# розничной	I-MET	10992	11001
# торговли	I-MET	11002	11010
# .	O	11010	11011
#
# В	O	11012	11013
# целом	O	11014	11019
# на	O	11020	11022
# малый	I-ECO	11023	11028
# бизнес	I-ECO	11029	11035
# приходится	O	11036	11046
# более	I-CMP	11047	11052
# 50	I-CMP	11053	11055
# %	I-CMP	11056	11057
# оборота	I-MET	11058	11065
# розничной	I-MET	11066	11075
# торговли	I-MET	11076	11084
# .	O	11084	11085
#
# Алтайский	I-INST	11086	11095
# край	I-INST	11096	11100
# занимает	I-BIN	11101	11109
# первое	O	11110	11116
# место	O	11117	11122
# среди	O	11123	11128
# регионов	I-INST	11129	11137
# Сибири	I-INST	11138	11144
# по	O	11145	11147
# показателю	I-MET	11148	11158
# количества	I-MET	11159	11169
# фактически	I-MET	11170	11180
# осуществляющих	I-MET	11181	11195
# деятельность	I-MET	11196	11208
# субъектов	I-MET	11209	11218
# малого	I-MET	11219	11225
# и	I-MET	11226	11227
# среднего	I-MET	11228	11236
# бизнеса	I-MET	11237	11244
# .	O	11244	11245
#
# В	O	11246	11247
# крае	O	11248	11252
# на	O	11253	11255
# одну	O	11256	11260
# тысячу	O	11261	11267
# человек	O	11268	11275
# населения	I-SOC	11276	11285
# приходится	O	11286	11296
# 36	O	11297	11299
# субъектов	I-ECO	11300	11309
# предпринимательства	I-ECO	11310	11329
# (	O	11330	11331
# 14	O	11331	11333
# место	O	11334	11339
# в	O	11340	11341
# Российской	I-INST	11342	11352
# Федерации	I-INST	11353	11362
# )	O	11362	11363
# .	O	11363	11364
#
# По	O	11365	11367
# объему	I-MET	11368	11374
# инвестиций	I-MET	11375	11385
# малого	I-MET	11386	11392
# предпринимательства	I-MET	11393	11412
# в	I-MET	11413	11414
# основной	I-MET	11415	11423
# капитал	I-MET	11424	11431
# край	O	11432	11436
# занимает	I-BIN	11437	11445
# 4	O	11446	11447
# место	O	11448	11453
# в	O	11454	11455
# Сибирском	I-INST	11456	11465
# федеральном	I-INST	11466	11477
# округе	I-INST	11478	11484
# .	O	11484	11485
#
# В	O	11486	11487
# 2011	O	11488	11492
# году	O	11493	11497
# количество	I-MET	11498	11508
# субъектов	I-MET	11509	11518
# малого	I-MET	11519	11525
# и	I-MET	11526	11527
# среднего	I-MET	11528	11536
# предпринимательства	I-MET	11537	11556
# составило	O	11557	11566
# в	O	11567	11568
# крае	O	11569	11573
# свыше	I-CMP	11574	11579
# 100	O	11580	11583
# тысяч	O	11584	11589
# единиц	O	11590	11596
# ,	O	11596	11597
# из	O	11598	11600
# них	O	11601	11604
# 0	O	11605	11606
# ,	O	11606	11607
# 5	O	11607	11608
# тысяч	O	11609	11614
# -	O	11615	11616
# средние	I-ECO	11617	11624
# предприятия	I-ECO	11625	11636
# ,	O	11636	11637
# 30	O	11638	11640
# ,	O	11640	11641
# 6	O	11641	11642
# тысяч	O	11643	11648
# -	O	11649	11650
# малые	I-ECO	11651	11656
# предприятия	I-ECO	11657	11668
# (	O	11669	11670
# включая	O	11670	11677
# микро	I-ECO	11678	11683
# предприятия	I-ECO	11684	11695
# )	O	11695	11696
# ,	O	11696	11697
# 69	O	11698	11700
# ,	O	11700	11701
# 4	O	11701	11702
# тысяч	O	11703	11708
# -	O	11709	11710
# индивидуальные	I-ECO	11711	11725
# предприниматели	I-ECO	11726	11741
# .	O	11741	11742
#
# Основными	O	11743	11752
# отличительными	O	11753	11767
# особенностями	O	11768	11781
# предпринимательства	I-ECO	11782	11801
# являются	O	11802	11810
# присутствие	I-BIN	11811	11822
# данной	O	11823	11829
# категории	O	11830	11839
# хозяйствующих	I-ECO	11840	11853
# субъектов	I-ECO	11854	11863
# во	O	11864	11866
# всех	O	11867	11871
# видах	I-ECO	11872	11877
# экономической	I-ECO	11878	11891
# деятельности	I-ECO	11892	11904
# ,	O	11904	11905
# осуществляемых	O	11906	11920
# на	O	11921	11923
# территории	I-ECO	11924	11934
# края	I-ECO	11935	11939
# ,	O	11939	11940
# а	O	11941	11942
# также	O	11943	11948
# высокая	I-QUA	11949	11956
# мобильность	I-MET	11957	11968
# ,	O	11968	11969
# обеспечивающая	O	11970	11984
# перемещение	O	11985	11996
# трудовых	I-ECO	11997	12005
# ,	I-ECO	12005	12006
# финансовых	I-ECO	12007	12017
# и	I-ECO	12018	12019
# материальных	I-ECO	12020	12032
# ресурсов	I-ECO	12033	12041
# в	O	12042	12043
# сферы	I-ECO	12044	12049
# повышенного	I-ECO	12050	12061
# спроса	I-ECO	12062	12068
# .	O	12068	12069
#
# По	O	12070	12072
# всем	O	12073	12077
# основным	I-MET	12078	12086
# индикаторам	I-MET	12087	12098
# динамика	B-MET	12099	12107
# развития	I-MET	12108	12116
# краевого	I-MET	12117	12125
# предпринимательства	I-MET	12126	12145
# характеризуется	O	12146	12161
# устойчивым	I-MET	12162	12172
# ростом	I-MET	12173	12179
# :	O	12179	12180
# с	O	12181	12182
# 2009	O	12183	12187
# по	O	12188	12190
# 2011	O	12191	12195
# годы	O	12196	12200
# в	O	12201	12202
# 1	O	12203	12204
# ,	O	12204	12205
# 4	O	12205	12206
# раза	O	12207	12211
# возросло	I-CMP	12212	12220
# число	I-MET	12221	12226
# малых	I-MET	12227	12232
# предприятий	I-MET	12233	12244
# ;	O	12244	12245
# в	O	12246	12247
# 1	O	12248	12249
# ,	O	12249	12250
# 5	O	12250	12251
# раза	O	12252	12256
# увеличился	I-CMP	12257	12267
# объем	I-MET	12268	12273
# отгруженных	I-MET	12274	12285
# товаров	I-MET	12286	12293
# собственного	I-MET	12294	12306
# производства	I-MET	12307	12319
# и	I-MET	12320	12321
# выручки	I-MET	12322	12329
# от	I-MET	12330	12332
# реализации	I-MET	12333	12343
# товаров	I-MET	12344	12351
# ,	I-MET	12351	12352
# выполнения	I-MET	12353	12363
# работ	I-MET	12364	12369
# ,	I-MET	12369	12370
# оказания	I-MET	12371	12379
# услуг	I-MET	12380	12385
# ;	O	12385	12386
# в	O	12387	12388
# 2	O	12389	12390
# ,	O	12390	12391
# 3	O	12391	12392
# раза	O	12393	12397
# -	O	12398	12399
# инвестиции	I-MET	12400	12410
# в	I-MET	12411	12412
# основной	I-MET	12413	12421
# капитал	I-MET	12422	12429
# малых	I-MET	12430	12435
# предприятий	I-MET	12436	12447
# .	O	12447	12448
#
# Три	O	12449	12452
# четверти	O	12453	12461
# от	O	12462	12464
# общего	I-MET	12465	12471
# числа	I-MET	12472	12477
# малых	I-MET	12478	12483
# предприятий	I-MET	12484	12495
# края	I-MET	12496	12500
# осуществляют	O	12501	12513
# деятельность	I-ACT	12514	12526
# в	I-ACT	12527	12528
# торговле	I-ACT	12529	12537
# ,	I-ACT	12537	12538
# строительстве	I-ACT	12539	12552
# ,	I-ACT	12552	12553
# обрабатывающей	I-ACT	12554	12568
# промышленности	I-ACT	12569	12583
# и	I-ACT	12584	12585
# в	I-ACT	12586	12587
# обслуживании	I-ACT	12588	12600
# оборота	I-ACT	12601	12608
# недвижимого	I-ACT	12609	12620
# имущества	I-ACT	12621	12630
# .	O	12630	12631
#
# Наибольший	I-MET	12632	12642
# удельный	I-MET	12643	12651
# вес	I-MET	12652	12655
# в	I-MET	12656	12657
# общем	I-MET	12658	12663
# количестве	I-MET	12664	12674
# субъектов	I-MET	12675	12684
# малого	I-MET	12685	12691
# и	I-MET	12692	12693
# среднего	I-MET	12694	12702
# бизнеса	I-MET	12703	12710
# Алтайского	I-MET	12711	12721
# края	I-MET	12722	12726
# занимают	I-BIN	12727	12735
# субъекты	I-ECO	12736	12744
# ,	I-ECO	12744	12745
# осуществляющие	I-ECO	12746	12760
# деятельность	I-ECO	12761	12773
# в	I-ECO	12774	12775
# торговле	I-ECO	12776	12784
# ,	O	12784	12785
# -	O	12786	12787
# 49	O	12788	12790
# ,	O	12790	12791
# 4	O	12791	12792
# %	O	12793	12794
# .	O	12794	12795
#
# Положительным	I-MET	12796	12809
# фактором	I-MET	12810	12818
# является	O	12819	12827
# увеличение	I-CMP	12828	12838
# на	O	12839	12841
# протяжении	O	12842	12852
# ряда	O	12853	12857
# последних	O	12858	12867
# лет	O	12868	12871
# доли	I-MET	12872	12876
# выручки	I-MET	12877	12884
# от	I-MET	12885	12887
# реализации	I-MET	12888	12898
# товаров	I-MET	12899	12906
# (	I-MET	12907	12908
# работ	I-MET	12908	12913
# ,	I-MET	12913	12914
# услуг	I-MET	12915	12920
# )	I-MET	12920	12921
# и	I-MET	12922	12923
# оборота	I-MET	12924	12931
# на	I-MET	12932	12934
# малых	I-MET	12935	12940
# предприятиях	I-MET	12941	12953
# (	I-MET	12954	12955
# без	I-MET	12955	12958
# учета	I-MET	12959	12964
# микро	I-MET	12965	12970
# предприятий	I-MET	12971	12982
# )	I-MET	12982	12983
# обрабатывающих	I-MET	12984	12998
# производств	I-MET	12999	13010
# ,	I-MET	13010	13011
# в	I-MET	13012	13013
# сельском	I-MET	13014	13022
# хозяйстве	I-MET	13023	13032
# ,	I-MET	13032	13033
# на	I-MET	13034	13036
# предприятиях	I-MET	13037	13049
# ,	I-MET	13049	13050
# оказывающих	I-MET	13051	13062
# транспортные	I-MET	13063	13075
# услуги	I-MET	13076	13082
# .	O	13082	13083
#
# Налоговые	I-MET	13084	13093
# поступления	I-MET	13094	13105
# в	I-MET	13106	13107
# консолидированный	I-MET	13108	13125
# бюджет	I-MET	13126	13132
# Алтайского	I-MET	13133	13143
# края	I-MET	13144	13148
# от	I-MET	13149	13151
# субъектов	I-MET	13152	13161
# малого	I-MET	13162	13168
# и	I-MET	13169	13170
# среднего	I-MET	13171	13179
# бизнеса	I-MET	13180	13187
# за	O	13188	13190
# 2009	O	13191	13195
# -	O	13196	13197
# 2011	O	13198	13202
# годы	O	13203	13207
# увеличились	I-CMP	13208	13219
# в	O	13220	13221
# 1	O	13222	13223
# ,	O	13223	13224
# 3	O	13224	13225
# раза	O	13226	13230
# .	O	13230	13231
#
# Темпы	I-MET	13232	13237
# роста	I-MET	13238	13243
# промышленного	I-MET	13244	13257
# производства	I-MET	13258	13270
# на	I-MET	13271	13273
# малых	I-MET	13274	13279
# предприятиях	I-MET	13280	13292
# в	O	13293	13294
# последние	O	13295	13304
# годы	O	13305	13309
# стабильно	I-QUA	13310	13319
# превышают	I-CMP	13320	13329
# рост	I-MET	13330	13334
# производства	I-MET	13335	13347
# на	I-MET	13348	13350
# крупных	I-MET	13351	13358
# и	I-MET	13359	13360
# средних	I-MET	13361	13368
# промышленных	I-MET	13369	13381
# предприятиях	I-MET	13382	13394
# .	O	13394	13395
#
# Огромную	I-QUA	13396	13404
# роль	O	13405	13409
# малый	I-ECO	13410	13415
# и	I-ECO	13416	13417
# средний	I-ECO	13418	13425
# бизнес	I-ECO	13426	13432
# края	O	13433	13437
# играет	I-BIN	13438	13444
# в	O	13445	13446
# сельской	I-ECO	13447	13455
# местности	I-ECO	13456	13465
# (	O	13466	13467
# как	O	13467	13470
# сельскохозяйственной	I-ECO	13471	13491
# ,	O	13491	13492
# так	O	13493	13496
# и	O	13497	13498
# не	I-ECO	13499	13501
# сельскохозяйственной	I-ECO	13502	13522
# направленности	I-ECO	13523	13537
# )	O	13537	13538
# ввиду	O	13539	13544
# значительного	I-QUA	13545	13558
# числа	I-MET	13559	13564
# сельских	I-MET	13565	13573
# муниципальных	I-MET	13574	13587
# образований	I-MET	13588	13599
# и	O	13600	13601
# высокой	I-QUA	13602	13609
# доли	I-MET	13610	13614
# сельского	I-MET	13615	13624
# населения	I-MET	13625	13634
# .	O	13634	13635
#
# Возобновившийся	O	13636	13651
# в	O	13652	13653
# регионе	O	13654	13661
# экономической	I-ECO	13662	13675
# рост	I-ECO	13676	13680
# позволил	I-BIN	13681	13689
# улучшить	I-CMP	13690	13698
# важнейшие	I-QUA	13699	13708
# социальные	I-MET	13709	13719
# параметры	I-MET	13720	13729
# ,	I-MET	13729	13730
# отражающие	I-MET	13731	13741
# уровень	I-MET	13742	13749
# жизни	I-MET	13750	13755
# населения	I-MET	13756	13765
# .	O	13765	13766
#
# В	O	13767	13768
# частности	O	13769	13778
# ,	O	13778	13779
# уровень	I-MET	13780	13787
# реальных	I-MET	13788	13796
# денежных	I-MET	13797	13805
# доходов	I-MET	13806	13813
# населения	I-MET	13814	13823
# в	O	13824	13825
# 2011	O	13826	13830
# году	O	13831	13835
# возрос	I-CMP	13836	13842
# на	O	13843	13845
# 4	O	13846	13847
# ,	O	13847	13848
# 8	O	13848	13849
# %	O	13850	13851
# ,	O	13851	13852
# что	O	13853	13856
# превосходит	I-CMP	13857	13868
# соответствующий	O	13869	13884
# прирост	I-CMP	13885	13892
# по	O	13893	13895
# Российской	I-INST	13896	13906
# Федерации	I-INST	13907	13916
# (	O	13917	13918
# 1	O	13918	13919
# ,	O	13919	13920
# 1	O	13920	13921
# %	O	13922	13923
# )	O	13923	13924
# и	O	13925	13926
# по	O	13927	13929
# Сибирскому	I-INST	13930	13940
# федеральному	I-INST	13941	13953
# округу	I-INST	13954	13960
# (	O	13961	13962
# 1	O	13962	13963
# ,	O	13963	13964
# 5	O	13964	13965
# %	O	13966	13967
# )	O	13967	13968
# .	O	13968	13969
#
# По	O	13970	13972
# темпу	I-MET	13973	13978
# роста	I-MET	13979	13984
# заработной	I-MET	13985	13995
# платы	I-MET	13996	14001
# (	O	14002	14003
# 114	O	14003	14006
# ,	O	14006	14007
# 7	O	14007	14008
# %	O	14009	14010
# к	O	14011	14012
# уровню	O	14013	14019
# 2010	O	14020	14024
# года	O	14025	14029
# )	O	14029	14030
# край	O	14031	14035
# занимает	I-BIN	14036	14044
# 1	O	14045	14046
# место	O	14047	14052
# в	O	14053	14054
# СФО	I-INST	14055	14058
# и	O	14059	14060
# 11	O	14061	14063
# место	O	14064	14069
# в	O	14070	14071
# России	I-INST	14072	14078
# .	O	14078	14079
#
# Демографическая	I-SOC	14080	14095
# ситуация	I-SOC	14096	14104
# в	O	14105	14106
# Алтайском	I-INST	14107	14116
# крае	I-INST	14117	14121
# характеризуется	O	14122	14137
# снижением	I-CMP	14138	14147
# ежегодным	O	14148	14157
# снижением	I-CMP	14158	14167
# убыли	I-MET	14168	14173
# населения	I-MET	14174	14183
# в	O	14184	14185
# среднем	O	14186	14193
# на	O	14194	14196
# 4	O	14197	14198
# тыс	O	14199	14202
# .	O	14202	14203
# человек	O	14204	14211
# .	O	14211	14212
#
# В	O	14213	14214
# 2011	O	14215	14219
# году	O	14220	14224
# относительно	O	14225	14237
# 2006	O	14238	14242
# года	O	14243	14247
# убыль	I-MET	14248	14253
# населения	I-MET	14254	14263
# сократилась	I-CMP	14264	14275
# в	O	14276	14277
# 2	O	14278	14279
# ...
# Сибирском	O	54238	54247
# Федеральном	O	54248	54259
# округе	O	54260	54266
# и	O	54267	54268
# третье	O	54269	54275
# -	O	54276	54277
# в	O	54278	54279
# Российской	O	54280	54290
# Федерации	O	54291	54300
# -	O	54301	54302
# 16692	O	54303	54308
# км	O	54309	54311
# .	O	54311	54312
#
# Доля	I-MET	54313	54317
# дорог	I-MET	54318	54323
# с	I-MET	54324	54325
# твердым	I-MET	54326	54333
# покрытием	I-MET	54334	54343
# составляет	O	54344	54354
# 87	O	54355	54357
# ,	O	54357	54358
# 4	O	54358	54359
# %	O	54360	54361
# ,	O	54361	54362
# обеспеченность	I-MET	54363	54377
# дорогами	I-MET	54378	54386
# общего	I-MET	54387	54393
# пользования	I-MET	54394	54405
# -	O	54406	54407
# 99	O	54408	54410
# ,	O	54410	54411
# 3	O	54411	54412
# км	O	54413	54415
# на	O	54416	54418
# 1	O	54419	54420
# кв	O	54421	54423
# .	O	54423	54424
# км	O	54425	54427
# площади	I-MET	54428	54435
# .	O	54435	54436
#
# На	O	54437	54439
# дорогах	I-ECO	54440	54447
# края	I-ECO	54448	54452
# расположены	O	54453	54464
# 768	O	54465	54468
# мостовых	I-ECO	54469	54477
# сооружения	I-ECO	54478	54488
# длиной	B-ECO	54489	54495
# 27043	O	54496	54501
# п	O	54502	54503
# .	O	54503	54504
# м	O	54505	54506
# .	O	54506	54507
#
# Основу	O	54508	54514
# транспортной	I-ECO	54515	54527
# инфраструктуры	I-ECO	54528	54542
# края	I-ECO	54543	54547
# составляют	O	54548	54558
# федеральные	I-ECO	54559	54570
# автодороги	I-ECO	54571	54581
# М	I-ECO	54582	54583
# -	I-ECO	54583	54584
# 52	I-ECO	54584	54586
# "	I-ECO	54587	54588
# Чуйский	I-ECO	54588	54595
# тракт	I-ECO	54596	54601
# "	I-ECO	54601	54602
# с	I-ECO	54603	54604
# подъездом	I-ECO	54605	54614
# к	I-ECO	54615	54616
# Барнаулу	I-ECO	54617	54625
# протяженностью	I-MET	54626	54640
# 306	O	54641	54644
# ,	O	54644	54645
# 0	O	54645	54646
# км	O	54647	54649
# и	O	54650	54651
# А	I-ECO	54652	54653
# -	I-ECO	54653	54654
# 349	I-ECO	54654	54657
# "	I-ECO	54658	54659
# Барнаул	I-ECO	54659	54666
# -	I-ECO	54667	54668
# Рубцовск	I-ECO	54669	54677
# -	I-ECO	54678	54679
# граница	I-ECO	54680	54687
# Казахстана	I-ECO	54688	54698
# "	I-ECO	54698	54699
# протяженностью	I-MET	54700	54714
# 321	O	54715	54718
# км	O	54719	54721
# ,	O	54721	54722
# а	O	54723	54724
# также	O	54725	54730
# автомобильные	I-ECO	54731	54744
# дороги	I-ECO	54745	54751
# регионального	I-ECO	54752	54765
# или	I-ECO	54766	54769
# меж	I-ECO	54770	54773
# муниципального	I-ECO	54774	54788
# значения	I-ECO	54789	54797
# .	O	54797	54798
#
# Ежегодно	O	54799	54807
# автомобильный	I-ECO	54808	54821
# транспорт	I-ECO	54822	54831
# общего	I-ECO	54832	54838
# пользования	I-ECO	54839	54850
# Алтайского	I-ECO	54851	54861
# края	I-ECO	54862	54866
# перевозит	O	54867	54876
# более	I-CMP	54877	54882
# 200	I-CMP	54883	54886
# млн	I-CMP	54887	54890
# .	I-CMP	54890	54891
# пассажиров	I-CMP	54892	54902
# ,	O	54902	54903
# что	O	54904	54907
# составляет	O	54908	54918
# 92	O	54919	54921
# %	O	54922	54923
# всего	O	54924	54929
# объема	I-MET	54930	54936
# перевозок	I-MET	54937	54946
# пассажиров	I-MET	54947	54957
# в	I-MET	54958	54959
# крае	I-MET	54960	54964
# ,	O	54964	54965
# выполняя	O	54966	54974
# 2	O	54975	54976
# млрд	O	54977	54981
# .	O	54981	54982
# пасс	O	54983	54987
# .	O	54987	54988
# -	O	54988	54989
# км	O	54989	54991
# или	O	54992	54995
# 67	O	54996	54998
# ,	O	54998	54999
# 4	O	54999	55000
# %	O	55001	55002
# общего	I-MET	55003	55009
# пассажиро	I-MET	55010	55019
# оборота	I-MET	55020	55027
# .	O	55027	55028
#
# По	O	55029	55031
# территории	O	55032	55042
# края	O	55043	55047
# проходят	O	55048	55056
# 53	O	55057	55059
# межрегиональных	I-ECO	55060	55075
# автобусных	I-ECO	55076	55086
# маршрута	I-ECO	55087	55095
# ,	O	55095	55096
# обеспечивая	O	55097	55108
# беспересадочное	O	55109	55124
# автобусное	I-ECO	55125	55135
# сообщение	I-ECO	55136	55145
# с	O	55146	55147
# соседними	O	55148	55157
# регионами	O	55158	55167
# Сибири	O	55168	55174
# (	O	55175	55176
# Омская	O	55176	55182
# ,	O	55182	55183
# Томская	O	55184	55191
# ,	O	55191	55192
# Новосибирская	O	55193	55206
# ,	O	55206	55207
# Кемеровская	O	55208	55219
# области	O	55220	55227
# ,	O	55227	55228
# Красноярский	O	55229	55241
# край	O	55242	55246
# и	O	55247	55248
# Республика	O	55249	55259
# Алтай	O	55260	55265
# )	O	55265	55266
# ,	O	55266	55267
# а	O	55268	55269
# также	O	55270	55275
# 35	O	55276	55278
# международных	I-ECO	55279	55292
# автобусных	I-ECO	55293	55303
# маршрутов	I-ECO	55304	55313
# ,	O	55313	55314
# связывающие	O	55315	55326
# Алтайский	O	55327	55336
# край	O	55337	55341
# и	O	55342	55343
# другие	O	55344	55350
# регионы	O	55351	55358
# Сибири	O	55359	55365
# с	O	55366	55367
# республиками	O	55368	55380
# Казахстан	O	55381	55390
# (	O	55391	55392
# Семипалатинск	O	55392	55405
# ,	O	55405	55406
# Усть	O	55407	55411
# -	O	55411	55412
# Каменогорск	O	55412	55423
# ,	O	55423	55424
# Жезкент	O	55425	55432
# ,	O	55432	55433
# Павлодар	O	55434	55442
# ,	O	55442	55443
# Караганда	O	55444	55453
# )	O	55453	55454
# ,	O	55454	55455
# Киргизстан	O	55456	55466
# (	O	55467	55468
# Бишкек	O	55468	55474
# )	O	55474	55475
# и	O	55476	55477
# Германией	O	55478	55487
# (	O	55488	55489
# Фрайбург	O	55489	55497
# )	O	55497	55498
# .	O	55498	55499
#
# Сеть	I-ECO	55500	55504
# автобусных	I-ECO	55505	55515
# маршрутов	I-ECO	55516	55525
# охватывает	O	55526	55536
# все	O	55537	55540
# города	I-ECO	55541	55547
# и	O	55548	55549
# райцентры	I-ECO	55550	55559
# ,	O	55559	55560
# а	O	55561	55562
# также	O	55563	55568
# 1254	O	55569	55573
# малых	I-CMP	55574	55579
# населенных	I-ECO	55580	55590
# пункта	I-ECO	55591	55597
# края	O	55598	55602
# .	O	55602	55603
#
# Всего	O	55604	55609
# в	O	55610	55611
# крае	O	55612	55616
# функционирует	O	55617	55630
# 886	O	55631	55634
# регулярных	I-ECO	55635	55645
# маршрутов	I-ECO	55646	55655
# общей	I-MET	55656	55661
# протяженностью	I-MET	55662	55676
# свыше	I-CMP	55677	55682
# 73	I-CMP	55683	55685
# тыс	I-CMP	55686	55689
# .	I-CMP	55689	55690
# км	I-CMP	55691	55693
# .	I-CMP	55693	55694
#
# На	O	55695	55697
# территории	O	55698	55708
# края	O	55709	55713
# работают	O	55714	55722
# 8	O	55723	55724
# автовокзалов	I-ECO	55725	55737
# ,	O	55737	55738
# 47	O	55739	55741
# пассажирских	I-ECO	55742	55754
# авто	I-ECO	55755	55759
# станций	I-ECO	55760	55767
# .	O	55767	55768
#
# Все	O	55769	55772
# автобусы	I-ECO	55773	55781
# ,	O	55781	55782
# осуществляющие	O	55783	55797
# перевозки	I-ACT	55798	55807
# пассажиров	I-ACT	55808	55818
# на	O	55819	55821
# регулярных	O	55822	55832
# меж	I-ECO	55833	55836
# муниципальных	I-ECO	55837	55850
# маршрутах	I-ECO	55851	55860
# междугороднего	I-ECO	55861	55875
# и	I-ECO	55876	55877
# пригородного	I-ECO	55878	55890
# сообщения	I-ECO	55891	55900
# ,	O	55900	55901
# оснащены	O	55902	55910
# приборами	O	55911	55920
# системы	O	55921	55928
# ГЛОНАСС	O	55929	55936
# .	O	55936	55937
#
# В	O	55938	55939
# структуру	O	55940	55949
# воздушного	I-ECO	55950	55960
# транспорта	I-ECO	55961	55971
# входят	O	55972	55978
# аэропорты	I-ECO	55979	55988
# городов	O	55989	55996
# Барнаула	O	55997	56005
# и	O	56006	56007
# Бийска	O	56008	56014
# .	O	56014	56015
#
# Международный	I-ECO	56016	56029
# аэропорт	I-ECO	56030	56038
# Барнаул	I-ECO	56039	56046
# имени	I-ECO	56047	56052
# Г	I-ECO	56053	56054
# .	I-ECO	56054	56055
# С	I-ECO	56055	56056
# .	I-ECO	56056	56057
# Титова	I-ECO	56058	56064
# имеет	O	56065	56070
# прямое	O	56071	56077
# авиа	I-ECO	56078	56082
# транспортное	I-ECO	56083	56095
# сообщение	I-ECO	56096	56105
# с	O	56106	56107
# городами	O	56108	56116
# :	O	56116	56117
# Москва	O	56118	56124
# ,	O	56124	56125
# Санкт	O	56126	56131
# -	O	56131	56132
# Петербург	O	56132	56141
# ,	O	56141	56142
# Красноярск	O	56143	56153
# ,	O	56153	56154
# Сочи	O	56155	56159
# ,	O	56159	56160
# Анапа	O	56161	56166
# ,	O	56166	56167
# Минеральные	O	56168	56179
# Воды	O	56180	56184
# ,	O	56184	56185
# Краснодар	O	56186	56195
# ,	O	56195	56196
# Душанбе	O	56197	56204
# ,	O	56204	56205
# Абакан	O	56206	56212
# ,	O	56212	56213
# Хабаровск	O	56214	56223
# ,	O	56223	56224
# Владивосток	O	56225	56236
# ,	O	56236	56237
# Иркутск	O	56238	56245
# ,	O	56245	56246
# Сургут	O	56247	56253
# ,	O	56253	56254
# Томск	O	56255	56260
# ,	O	56260	56261
# Нижневартовск	O	56262	56275
# ,	O	56275	56276
# Норильск	O	56277	56285
# ,	O	56285	56286
# Ростов	O	56287	56293
# -	O	56293	56294
# на	O	56294	56296
# -	O	56296	56297
# Дону	O	56297	56301
# .	O	56301	56302
#
# Международные	I-ECO	56303	56316
# рейсы	I-ECO	56317	56322
# осуществляются	O	56323	56337
# в	O	56338	56339
# Анталью	O	56340	56347
# ,	O	56347	56348
# Бангкок	O	56349	56356
# ,	O	56356	56357
# Ираклион	O	56358	56366
# (	O	56367	56368
# новое	O	56368	56373
# для	O	56374	56377
# Алтайского	O	56378	56388
# края	O	56389	56393
# направление	O	56394	56405
# )	O	56405	56406
# ,	O	56406	56407
# Дюссельдорф	O	56408	56419
# и	O	56420	56421
# китайский	O	56422	56431
# город	O	56432	56437
# Урумчи	O	56438	56444
# ,	O	56444	56445
# рейсы	O	56446	56451
# на	O	56452	56454
# данном	O	56455	56461
# направлении	O	56462	56473
# в	O	56474	56475
# конце	O	56476	56481
# 2011	O	56482	56486
# года	O	56487	56491
# начала	O	56492	56498
# выполнять	O	56499	56508
# авиакомпания	I-INST	56509	56521
# "	I-INST	56522	56523
# РусЛайн	I-INST	56523	56530
# "	I-INST	56530	56531
# .	O	56531	56532
#
# Аэропорт	I-ECO	56533	56541
# ,	O	56541	56542
# наряду	O	56543	56549
# с	O	56550	56551
# пассажирскими	I-ECO	56552	56565
# авиа	I-ECO	56566	56570
# рейсами	O	56571	56578
# ,	O	56578	56579
# осуществляет	O	56580	56592
# обслуживание	I-ACT	56593	56605
# грузовых	I-ACT	56606	56614
# и	I-ACT	56615	56616
# почтовых	I-ACT	56617	56625
# авиа	I-ACT	56626	56630
# рейсов	I-ACT	56631	56637
# ,	O	56637	56638
# имеет	O	56639	56644
# одну	O	56645	56649
# взлетно	I-ECO	56650	56657
# -	I-ECO	56657	56658
# посадочную	I-ECO	56658	56668
# полосу	I-ECO	56669	56675
# класса	I-ECO	56676	56682
# В	I-ECO	56683	56684
# длиной	I-MET	56685	56691
# 2850	O	56692	56696
# метров	O	56697	56703
# ,	O	56703	56704
# обслуживается	O	56705	56718
# в	O	56719	56720
# год	O	56721	56724
# более	I-CMP	56725	56730
# двух	I-CMP	56731	56735
# тысяч	I-CMP	56736	56741
# воздушных	I-ECO	56742	56751
# судов	I-ECO	56752	56757
# разных	O	56758	56764
# типов	O	56765	56770
# .	O	56770	56771
#
# Важной	I-QUA	56772	56778
# составляющей	O	56779	56791
# транспортной	I-ECO	56792	56804
# инфраструктуры	I-ECO	56805	56819
# края	I-ECO	56820	56824
# является	O	56825	56833
# аэропорт	I-ECO	56834	56842
# Бийска	I-ECO	56843	56849
# .	O	56849	56850
#
# С	O	56851	56852
# момента	O	56853	56860
# ввода	I-BIN	56861	56866
# в	I-BIN	56867	56868
# эксплуатацию	I-BIN	56869	56881
# аэропорт	I-ECO	56882	56890
# принимал	O	56891	56899
# воздушные	I-ECO	56900	56909
# суда	I-ECO	56910	56914
# третьего	I-ECO	56915	56923
# класса	I-ECO	56924	56930
# .	O	56930	56931
#
# С	O	56932	56933
# развитием	I-BIN	56934	56943
# экономической	I-ECO	56944	56957
# зоны	I-ECO	56958	56962
# туристско	I-ECO	56963	56972
# -	I-ECO	56972	56973
# рекреационного	I-ECO	56973	56987
# типа	I-ECO	56988	56992
# "	I-ECO	56993	56994
# Бирюзовая	I-ECO	56994	57003
# Катунь	I-ECO	57004	57010
# "	I-ECO	57010	57011
# ,	O	57011	57012
# игорной	I-SOC	57013	57020
# зоны	I-SOC	57021	57025
# "	I-SOC	57026	57027
# Сибирская	I-SOC	57027	57036
# монета	I-SOC	57037	57043
# "	I-SOC	57043	57044
# и	O	57045	57046
# города	I-ECO	57047	57053
# -	I-ECO	57053	57054
# курорта	I-ECO	57054	57061
# Белокурихи	O	57062	57072
# предполагается	O	57073	57087
# проведение	O	57088	57098
# реконструкции	I-BIN	57099	57112
# аэродрома	I-ECO	57113	57122
# аэропорта	I-ECO	57123	57132
# ,	O	57132	57133
# в	O	57134	57135
# результате	O	57136	57146
# которой	O	57147	57154
# станет	O	57155	57161
# возможным	O	57162	57171
# прием	I-ACT	57172	57177
# и	I-ACT	57178	57179
# обслуживание	I-ACT	57180	57192
# воздушных	I-ACT	57193	57202
# судов	I-ACT	57203	57208
# всех	I-ACT	57209	57213
# классов	I-ACT	57214	57221
# (	I-ACT	57222	57223
# кроме	I-ACT	57223	57228
# "	I-ACT	57229	57230
# Боинг	I-ACT	57230	57235
# -	I-ACT	57235	57236
# 747	I-ACT	57236	57239
# "	I-ACT	57239	57240
# )	I-ACT	57240	57241
# .	O	57241	57242
#
# Внутренние	I-ECO	57243	57253
# водные	I-ECO	57254	57260
# пути	I-ECO	57261	57265
# Алтайского	I-ECO	57266	57276
# края	I-ECO	57277	57281
# представлены	O	57282	57294
# судоходными	I-ECO	57295	57306
# реками	I-ECO	57307	57313
# Обь	I-ECO	57314	57317
# ,	I-ECO	57317	57318
# Бия	I-ECO	57319	57322
# ,	I-ECO	57322	57323
# Катунь	I-ECO	57324	57330
# .	O	57330	57331
#
# Общая	I-MET	57332	57337
# протяженность	I-MET	57338	57351
# судоходных	I-MET	57352	57362
# внутренних	I-MET	57363	57373
# водных	I-MET	57374	57380
# путей	I-MET	57381	57386
# общего	I-MET	57387	57393
# пользования	I-MET	57394	57405
# -	O	57406	57407
# 781	O	57408	57411
# км	O	57412	57414
# .	O	57414	57415
#
# Основные	I-ECO	57416	57424
# речные	I-ECO	57425	57431
# порты	I-ECO	57432	57437
# -	O	57438	57439
# Барнаульский	O	57440	57452
# ,	O	57452	57453
# Бийский	O	57454	57461
# ,	O	57461	57462
# Камень	O	57463	57469
# -	O	57469	57470
# на	O	57470	57472
# -	O	57472	57473
# Оби	O	57473	57476
# .	O	57476	57477
#
# Протяженность	I-MET	57478	57491
# магистральных	I-MET	57492	57505
# газопроводов	I-MET	57506	57518
# в	I-MET	57519	57520
# одно	I-MET	57521	57525
# ниточном	I-MET	57526	57534
# исполнении	I-MET	57535	57545
# в	I-MET	57546	57547
# границах	I-MET	57548	57556
# края	I-MET	57557	57561
# -	O	57562	57563
# 0	O	57564	57565
# ,	O	57565	57566
# 6	O	57566	57567
# тыс	O	57568	57571
# .	O	57571	57572
# км	O	57573	57575
# ,	O	57575	57576
# с	O	57577	57578
# учетом	O	57579	57585
# распределительных	I-ECO	57586	57603
# газовых	I-ECO	57604	57611
# сетей	I-ECO	57612	57617
# -	O	57618	57619
# 3	O	57620	57621
# ,	O	57621	57622
# 0	O	57622	57623
# тыс	O	57624	57627
# .	O	57627	57628
# км	O	57629	57631
# .	O	57631	57632
#
# 2	O	57634	57635
# .	O	57635	57636
# 4	O	57636	57637
# .	O	57637	57638
# 3	O	57638	57639
# .	O	57639	57640
#
# Информационно	I-ECO	57641	57654
# -	I-ECO	57654	57655
# коммуникационная	I-ECO	57655	57671
# система	I-ECO	57672	57679
#
# Одной	O	57681	57686
# из	O	57687	57689
# динамично	I-QUA	57690	57699
# развивающихся	O	57700	57713
# отраслей	O	57714	57722
# края	O	57723	57727
# является	O	57728	57736
# связь	O	57737	57742
# .	O	57742	57743
#
# Особенно	I-QUA	57744	57752
# высокими	I-QUA	57753	57761
# темпами	O	57762	57769
# развиваются	I-BIN	57770	57781
# новые	O	57782	57787
# системы	I-ECO	57788	57795
# связи	I-ECO	57796	57801
# ,	I-ECO	57801	57802
# ориентированные	I-ECO	57803	57818
# на	I-ECO	57819	57821
# использование	I-ECO	57822	57835
# стандарта	I-ECO	57836	57845
# GSM	I-ECO	57846	57849
# для	I-ECO	57850	57853
# мобильной	I-ECO	57854	57863
# связи	I-ECO	57864	57869
# ,	I-ECO	57869	57870
# IP	B-ECO	57871	57873
# -	I-ECO	57873	57874
# телефония	I-ECO	57874	57883
# ,	O	57883	57884
# предоставляются	I-BIN	57885	57900
# услуги	I-SOC	57901	57907
# факсимильной	I-SOC	57908	57920
# связи	I-SOC	57921	57926
# и	I-SOC	57927	57928
# Интернета	I-SOC	57929	57938
# .	O	57938	57939
#
# Мобильной	I-ECO	57940	57949
# связью	I-ECO	57950	57956
# покрыто	O	57957	57964
# 82	O	57965	57967
# -	O	57968	57969
# 91	O	57970	57972
# %	O	57973	57974
# всей	O	57975	57979
# площади	I-MET	57980	57987
# региона	I-MET	57988	57995
# .	O	57995	57996
#
# В	O	57997	57998
# числе	O	57999	58004
# крупных	I-QUA	58005	58012
# операторов	I-INST	58013	58023
# сотовой	I-INST	58024	58031
# связи	I-INST	58032	58037
# на	O	58038	58040
# территории	O	58041	58051
# края	O	58052	58056
# работают	O	58057	58065
# :	O	58065	58066
# Барнаульский	I-INST	58067	58079
# филиал	I-INST	58080	58086
# ОАО	I-INST	58087	58090
# "	I-INST	58091	58092
# Вымпелком	I-INST	58092	58101
# "	I-INST	58101	58102
# (	I-INST	58103	58104
# Билайн	I-INST	58104	58110
# )	I-INST	58110	58111
# ,	O	58111	58112
# Алтайское	I-INST	58113	58122
# отделение	I-INST	58123	58132
# ЗАО	I-INST	58133	58136
# "	I-INST	58137	58138
# Мобиком	I-INST	58138	58145
# -	I-INST	58145	58146
# Новосибирск	I-INST	58146	58157
# "	I-INST	58157	58158
# (	I-INST	58159	58160
# Мегафон	I-INST	58160	58167
# -	I-INST	58167	58168
# Сибирь	I-INST	58168	58174
# )	I-INST	58174	58175
# ,	O	58175	58176
# филиал	I-INST	58177	58183
# ОАО	I-INST	58184	58187
# "	I-INST	58188	58189
# Мобильные	I-INST	58189	58198
# телесистемы	I-INST	58199	58210
# "	I-INST	58210	58211
# (	I-INST	58212	58213
# МТС	I-INST	58213	58216
# )	I-INST	58216	58217
# ,	O	58217	58218
# ЗАО	I-INST	58219	58222
# "	I-INST	58223	58224
# Южно	I-INST	58224	58228
# -	I-INST	58228	58229
# Сибирская	I-INST	58229	58238
# сотовая	I-INST	58239	58246
# связь	I-INST	58247	58252
# "	I-INST	58252	58253
# (	I-INST	58254	58255
# СкайЛинк	I-INST	58255	58263
# )	I-INST	58263	58264
# ,	O	58264	58265
# ОАО	I-INST	58266	58269
# "	I-INST	58270	58271
# Алтайсвязь	I-INST	58271	58281
# "	I-INST	58281	58282
# .	O	58282	58283
#
# Крупным	I-QUA	58284	58291
# событием	O	58292	58300
# в	O	58301	58302
# развитии	I-BIN	58303	58311
# сотовой	I-ECO	58312	58319
# связи	I-ECO	58320	58325
# региона	I-ECO	58326	58333
# стало	O	58334	58339
# внедрение	I-BIN	58340	58349
# сетей	I-ECO	58350	58355
# нового	I-ECO	58356	58362
# поколения	I-ECO	58363	58372
# -	I-ECO	58373	58374
# стандарта	I-ECO	58375	58384
# 3G	I-ECO	58385	58387
# .	O	58387	58388
#
# Доля	I-MET	58389	58393
# такого	I-MET	58394	58400
# оборудования	I-MET	58401	58413
# третьего	I-MET	58414	58422
# поколения	I-MET	58423	58432
# достигает	I-BIN	58433	58442
# до	O	58443	58445
# 40	O	58446	58448
# %	O	58449	58450
# и	O	58451	58452
# неуклонно	I-QUA	58453	58462
# растет	I-CMP	58463	58469
# .	O	58469	58470

# %%
def iob_to_brat(conll: Iterable[str], text: str) -> Iterable[Entity]:
    entity_id = 1
    entity = None
    for s in conll:
        if not s:
            continue
        token, label, start_str, end_str = s.split('\t')
        start, end = int(start_str), int(end_str)
        if entity:
            if label == 'O':
                yield entity
                entity = None
            elif label.startswith('B-') or label[2:] != entity.label:
                yield entity
                entity = Entity(f'T{entity_id}', label[2:], Position(start, end), text[start: end])
                entity_id += 1
            else:
                assert label == 'I-' + entity.label
                entity = Entity(entity.id, 
                                entity.label, 
                                Position(entity.position.start, end), 
                                text[entity.position.start: end])
            continue
        if label == 'O':
            continue
        entity = Entity(f'T{entity_id}', label[2:], Position(start, end), text[start: end])
        entity_id += 1
    if entity:
        yield entity

# %%
'T25	MET 907 948	Средне годовая численность населения края'
# Out:
# 'T25\tMET 907 948\tСредне годовая численность населения края'

# %%
annotation_new = list(iob_to_brat(build_iob(text, sentences, annotation), text))

# %%
for i, (e1, e2) in enumerate(zip(annotation, annotation_new)):
    if e1.label != e2.label:
        print(e1, e2)
    if e1.text != e2.text:
        print(e1, e2)
# Out:
# Entity(id='T917', label='QUA', position=Position(start=32454, end=32471), text='один из крупнейши') Entity(id='T887', label='QUA', position=Position(start=32454, end=32461), text='один из')
# Entity(id='T1203', label='ECO', position=Position(start=44532, end=44612), text='общий сайт в сети Интернет "Алтай транс граничный" (http://www.altaiinter.ECOo/)') Entity(id='T1173', label='ECO', position=Position(start=44532, end=44612), text='общий сайт в сети Интернет "Алтай транс граничный" (http://www.altaiinter.info/)')
# Entity(id='T1456', label='ECO', position=Position(start=56552, end=56577), text='пассажирскими авиа рейсам') Entity(id='T1426', label='ECO', position=Position(start=56552, end=56570), text='пассажирскими авиа')

# %%
annotation_new[886]
# Out:
# Entity(id='T887', label='QUA', position=Position(start=32454, end=32461), text='один из')

# %%
annotation[886]
# Out:
# Entity(id='T917', label='QUA', position=Position(start=32454, end=32471), text='один из крупнейши')

# %%
text[56552: 56577]
# Out:
# 'пассажирскими авиа рейсам'
